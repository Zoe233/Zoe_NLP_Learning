# %%
# 上下文语境

# %%
# 通过增加特征提取函数，我们可以修改词性标注器来利用各种词内部的其他特征，如：词长、它所包含的音节数或者它的前缀。
# 特征提取器仅仅只看目标词，我们没法添加依赖词出现的上下文语境特征。
# 然而上下文语境特征往往提供关于正确标记的强大线索。
# 如：a fly, fly前面的词是a可以确定fly是一个名词，而不是动词。

# %%
# 为了采取基于词的上下文的特征，我们必须修改以前为我们的特征提取器的定义的模式。
# 不是只传递已标注的词，我们将传递整个（未标注的）句子，以及目标词的索引。

# %%
import nltk
from nltk.corpus import brown

# %%
def pos_features(sentence,i):
    '''
    词性分类器，它的特征检测器检查一个词出现的上下文以便决定应该分配的词性标记。
    特别的，前面的词被作为一个特征。
    '''
    features = {'suffix(1)':sentence[i][-1:],
               'suffix(2)':sentence[i][-2:],
               'suffix(3)':sentence[i][-3:]}
    if i == 0:
        features['prev-word'] = '<START>'
    else:
        features['prev-word'] = sentence[i-1]
    return features

# %%
pos_features(brown.sents()[0],8)  # 获取sentence的第8个词的3个后缀特征，加上第7个词的值。
# Out:
# {'prev-word': 'an', 'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion'}

# %%
tagged_sents = brown.tagged_sents(categories='news')

# %%
featuresets = []
for tagged_sent in tagged_sents:
    untagged_sent = nltk.tag.untag(tagged_sent)
    for i,(word,tag) in enumerate(tagged_sent):
        featuresets.append((pos_features(untagged_sent, i),tag))

# %%
featuresets
# Out:
# [({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ton'},
#   'NP-TL'),
#  ({'prev-word': 'Fulton',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ty',
#    'suffix(3)': 'nty'},
#   'NN-TL'),
#  ({'prev-word': 'County',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'JJ-TL'),
#  ({'prev-word': 'Grand',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ury'},
#   'NN-TL'),
#  ({'prev-word': 'Jury',
#    'suffix(1)': 'd',
#    'suffix(2)': 'id',
#    'suffix(3)': 'aid'},
#   'VBD'),
#  ({'prev-word': 'said',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ay',
#    'suffix(3)': 'day'},
#   'NR'),
#  ({'prev-word': 'Friday',
#    'suffix(1)': 'n',
#    'suffix(2)': 'an',
#    'suffix(3)': 'an'},
#   'AT'),
#  ({'prev-word': 'an', 'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'investigation',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 's', 'suffix(2)': "'s", 'suffix(3)': "a's"},
#   'NP$'),
#  ({'prev-word': "Atlanta's",
#    'suffix(1)': 't',
#    'suffix(2)': 'nt',
#    'suffix(3)': 'ent'},
#   'JJ'),
#  ({'prev-word': 'recent',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ary'},
#   'NN'),
#  ({'prev-word': 'primary',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'election',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ced'},
#   'VBD'),
#  ({'prev-word': 'produced',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'o', 'suffix(2)': 'no', 'suffix(3)': 'no'},
#   'AT'),
#  ({'prev-word': 'no', 'suffix(1)': 'e', 'suffix(2)': 'ce', 'suffix(3)': 'nce'},
#   'NN'),
#  ({'prev-word': 'evidence',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': 't', 'suffix(2)': 'at', 'suffix(3)': 'hat'},
#   'CS'),
#  ({'prev-word': 'that',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ny',
#    'suffix(3)': 'any'},
#   'DTI'),
#  ({'prev-word': 'any',
#    'suffix(1)': 's',
#    'suffix(2)': 'es',
#    'suffix(3)': 'ies'},
#   'NNS'),
#  ({'prev-word': 'irregularities',
#    'suffix(1)': 'k',
#    'suffix(2)': 'ok',
#    'suffix(3)': 'ook'},
#   'VBD'),
#  ({'prev-word': 'took',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ce',
#    'suffix(3)': 'ace'},
#   'NN'),
#  ({'prev-word': 'place', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ury'},
#   'NN'),
#  ({'prev-word': 'jury',
#    'suffix(1)': 'r',
#    'suffix(2)': 'er',
#    'suffix(3)': 'her'},
#   'RBR'),
#  ({'prev-word': 'further',
#    'suffix(1)': 'd',
#    'suffix(2)': 'id',
#    'suffix(3)': 'aid'},
#   'VBD'),
#  ({'prev-word': 'said',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'd', 'suffix(2)': 'nd', 'suffix(3)': 'end'},
#   'NN'),
#  ({'prev-word': 'term-end',
#    'suffix(1)': 's',
#    'suffix(2)': 'ts',
#    'suffix(3)': 'nts'},
#   'NNS'),
#  ({'prev-word': 'presentments',
#    'suffix(1)': 't',
#    'suffix(2)': 'at',
#    'suffix(3)': 'hat'},
#   'CS'),
#  ({'prev-word': 'that',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ty',
#    'suffix(3)': 'ity'},
#   'NN-TL'),
#  ({'prev-word': 'City',
#    'suffix(1)': 'e',
#    'suffix(2)': 've',
#    'suffix(3)': 'ive'},
#   'JJ-TL'),
#  ({'prev-word': 'Executive',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ee',
#    'suffix(3)': 'tee'},
#   'NN-TL'),
#  ({'prev-word': 'Committee',
#    'suffix(1)': ',',
#    'suffix(2)': ',',
#    'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'h', 'suffix(2)': 'ch', 'suffix(3)': 'ich'},
#   'WDT'),
#  ({'prev-word': 'which',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ad',
#    'suffix(3)': 'had'},
#   'HVD'),
#  ({'prev-word': 'had',
#    'suffix(1)': 'l',
#    'suffix(2)': 'll',
#    'suffix(3)': 'all'},
#   'JJ'),
#  ({'prev-word': 'over-all',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ge',
#    'suffix(3)': 'rge'},
#   'NN'),
#  ({'prev-word': 'charge',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'election',
#    'suffix(1)': ',',
#    'suffix(2)': ',',
#    'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': '`', 'suffix(2)': '``', 'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 's', 'suffix(2)': 'es', 'suffix(3)': 'ves'},
#   'VBZ'),
#  ({'prev-word': 'deserves',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'e',
#    'suffix(2)': 'se',
#    'suffix(3)': 'ise'},
#   'NN'),
#  ({'prev-word': 'praise',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 's',
#    'suffix(2)': 'ks',
#    'suffix(3)': 'nks'},
#   'NNS'),
#  ({'prev-word': 'thanks',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ty',
#    'suffix(3)': 'ity'},
#   'NN-TL'),
#  ({'prev-word': 'City',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN-TL'),
#  ({'prev-word': 'of', 'suffix(1)': 'a', 'suffix(2)': 'ta', 'suffix(3)': 'nta'},
#   'NP-TL'),
#  ({'prev-word': 'Atlanta',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': 'r', 'suffix(2)': 'or', 'suffix(3)': 'for'},
#   'IN'),
#  ({'prev-word': 'for',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'r',
#    'suffix(2)': 'er',
#    'suffix(3)': 'ner'},
#   'NN'),
#  ({'prev-word': 'manner',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'h', 'suffix(2)': 'ch', 'suffix(3)': 'ich'},
#   'WDT'),
#  ({'prev-word': 'which',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'election',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'was'},
#   'BEDZ'),
#  ({'prev-word': 'was',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ted'},
#   'VBN'),
#  ({'prev-word': 'conducted',
#    'suffix(1)': '.',
#    'suffix(2)': '.',
#    'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 'r',
#    'suffix(2)': 'er',
#    'suffix(3)': 'ber'},
#   'NP'),
#  ({'prev-word': 'September-October',
#    'suffix(1)': 'm',
#    'suffix(2)': 'rm',
#    'suffix(3)': 'erm'},
#   'NN'),
#  ({'prev-word': 'term',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ury'},
#   'NN'),
#  ({'prev-word': 'jury',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ad',
#    'suffix(3)': 'had'},
#   'HVD'),
#  ({'prev-word': 'had',
#    'suffix(1)': 'n',
#    'suffix(2)': 'en',
#    'suffix(3)': 'een'},
#   'BEN'),
#  ({'prev-word': 'been',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ged'},
#   'VBN'),
#  ({'prev-word': 'charged',
#    'suffix(1)': 'y',
#    'suffix(2)': 'by',
#    'suffix(3)': 'by'},
#   'IN'),
#  ({'prev-word': 'by', 'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ton'},
#   'NP-TL'),
#  ({'prev-word': 'Fulton',
#    'suffix(1)': 'r',
#    'suffix(2)': 'or',
#    'suffix(3)': 'ior'},
#   'JJ-TL'),
#  ({'prev-word': 'Superior',
#    'suffix(1)': 't',
#    'suffix(2)': 'rt',
#    'suffix(3)': 'urt'},
#   'NN-TL'),
#  ({'prev-word': 'Court',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ge',
#    'suffix(3)': 'dge'},
#   'NN-TL'),
#  ({'prev-word': 'Judge',
#    'suffix(1)': 'd',
#    'suffix(2)': 'od',
#    'suffix(3)': 'ood'},
#   'NP'),
#  ({'prev-word': 'Durwood',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ye',
#    'suffix(3)': 'Pye'},
#   'NP'),
#  ({'prev-word': 'Pye', 'suffix(1)': 'o', 'suffix(2)': 'to', 'suffix(3)': 'to'},
#   'TO'),
#  ({'prev-word': 'to', 'suffix(1)': 'e', 'suffix(2)': 'te', 'suffix(3)': 'ate'},
#   'VB'),
#  ({'prev-word': 'investigate',
#    'suffix(1)': 's',
#    'suffix(2)': 'ts',
#    'suffix(3)': 'rts'},
#   'NNS'),
#  ({'prev-word': 'reports',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'e', 'suffix(2)': 'le', 'suffix(3)': 'ble'},
#   'JJ'),
#  ({'prev-word': 'possible',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 's', 'suffix(2)': 'es', 'suffix(3)': 'ies'},
#   'NNS'),
#  ({'prev-word': 'irregularities',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': 'n', 'suffix(2)': 'in', 'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 't',
#    'suffix(2)': 'ht',
#    'suffix(3)': 'ght'},
#   'JJ'),
#  ({'prev-word': 'hard-fought',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ary'},
#   'NN'),
#  ({'prev-word': 'primary',
#    'suffix(1)': 'h',
#    'suffix(2)': 'ch',
#    'suffix(3)': 'ich'},
#   'WDT'),
#  ({'prev-word': 'which',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'was'},
#   'BEDZ'),
#  ({'prev-word': 'was',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'won'},
#   'VBN'),
#  ({'prev-word': 'won', 'suffix(1)': 'y', 'suffix(2)': 'by', 'suffix(3)': 'by'},
#   'IN'),
#  ({'prev-word': 'by', 'suffix(1)': 'e', 'suffix(2)': 'te', 'suffix(3)': 'ate'},
#   'NN-TL'),
#  ({'prev-word': 'Mayor-nominate',
#    'suffix(1)': 'n',
#    'suffix(2)': 'an',
#    'suffix(3)': 'van'},
#   'NP'),
#  ({'prev-word': 'Ivan',
#    'suffix(1)': 'n',
#    'suffix(2)': 'en',
#    'suffix(3)': 'len'},
#   'NP'),
#  ({'prev-word': 'Allen',
#    'suffix(1)': '.',
#    'suffix(2)': 'r.',
#    'suffix(3)': 'Jr.'},
#   'NP'),
#  ({'prev-word': 'Jr.', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'y', 'suffix(2)': 'ly', 'suffix(3)': 'nly'},
#   'RB'),
#  ({'prev-word': 'Only', 'suffix(1)': 'a', 'suffix(2)': 'a', 'suffix(3)': 'a'},
#   'AT'),
#  ({'prev-word': 'a', 'suffix(1)': 'e', 'suffix(2)': 've', 'suffix(3)': 'ive'},
#   'JJ'),
#  ({'prev-word': 'relative',
#    'suffix(1)': 'l',
#    'suffix(2)': 'ul',
#    'suffix(3)': 'ful'},
#   'NN'),
#  ({'prev-word': 'handful',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'h', 'suffix(2)': 'ch', 'suffix(3)': 'uch'},
#   'JJ'),
#  ({'prev-word': 'such',
#    'suffix(1)': 's',
#    'suffix(2)': 'ts',
#    'suffix(3)': 'rts'},
#   'NNS'),
#  ({'prev-word': 'reports',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'was'},
#   'BEDZ'),
#  ({'prev-word': 'was',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ved'},
#   'VBN'),
#  ({'prev-word': 'received',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': ',', 'suffix(2)': ',', 'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ury'},
#   'NN'),
#  ({'prev-word': 'jury',
#    'suffix(1)': 'd',
#    'suffix(2)': 'id',
#    'suffix(3)': 'aid'},
#   'VBD'),
#  ({'prev-word': 'said', 'suffix(1)': ',', 'suffix(2)': ',', 'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': '`', 'suffix(2)': '``', 'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'g', 'suffix(2)': 'ng', 'suffix(3)': 'ing'},
#   'IN'),
#  ({'prev-word': 'considering',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ad',
#    'suffix(3)': 'ead'},
#   'JJ'),
#  ({'prev-word': 'widespread',
#    'suffix(1)': 't',
#    'suffix(2)': 'st',
#    'suffix(3)': 'est'},
#   'NN'),
#  ({'prev-word': 'interest',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'election',
#    'suffix(1)': ',',
#    'suffix(2)': ',',
#    'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'r',
#    'suffix(2)': 'er',
#    'suffix(3)': 'ber'},
#   'NN'),
#  ({'prev-word': 'number',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 's', 'suffix(2)': 'rs', 'suffix(3)': 'ers'},
#   'NNS'),
#  ({'prev-word': 'voters',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ze',
#    'suffix(3)': 'ize'},
#   'NN'),
#  ({'prev-word': 'size',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 's', 'suffix(2)': 'is', 'suffix(3)': 'his'},
#   'DT'),
#  ({'prev-word': 'this',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ty',
#    'suffix(3)': 'ity'},
#   'NN'),
#  ({'prev-word': 'city',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ury'},
#   'NN'),
#  ({'prev-word': 'jury',
#    'suffix(1)': 'd',
#    'suffix(2)': 'id',
#    'suffix(3)': 'aid'},
#   'VBD'),
#  ({'prev-word': 'said',
#    'suffix(1)': 't',
#    'suffix(2)': 'it',
#    'suffix(3)': 'it'},
#   'PPS'),
#  ({'prev-word': 'it', 'suffix(1)': 'd', 'suffix(2)': 'id', 'suffix(3)': 'did'},
#   'DOD'),
#  ({'prev-word': 'did',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'ind'},
#   'VB'),
#  ({'prev-word': 'find',
#    'suffix(1)': 't',
#    'suffix(2)': 'at',
#    'suffix(3)': 'hat'},
#   'CS'),
#  ({'prev-word': 'that',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ny',
#    'suffix(3)': 'any'},
#   'AP'),
#  ({'prev-word': 'many',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 's', 'suffix(2)': "'s", 'suffix(3)': "a's"},
#   'NP$'),
#  ({'prev-word': "Georgia's",
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'registration',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'election',
#    'suffix(1)': 's',
#    'suffix(2)': 'ws',
#    'suffix(3)': 'aws'},
#   'NNS'),
#  ({'prev-word': 'laws',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'e', 'suffix(2)': 're', 'suffix(3)': 'are'},
#   'BER'),
#  ({'prev-word': 'are',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ded'},
#   'JJ'),
#  ({'prev-word': 'outmoded',
#    'suffix(1)': 'r',
#    'suffix(2)': 'or',
#    'suffix(3)': 'or'},
#   'CC'),
#  ({'prev-word': 'or', 'suffix(1)': 'e', 'suffix(2)': 'te', 'suffix(3)': 'ate'},
#   'JJ'),
#  ({'prev-word': 'inadequate',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 'n',
#    'suffix(2)': 'en',
#    'suffix(3)': 'ten'},
#   'RB'),
#  ({'prev-word': 'often',
#    'suffix(1)': 's',
#    'suffix(2)': 'us',
#    'suffix(3)': 'ous'},
#   'JJ'),
#  ({'prev-word': 'ambiguous',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 't',
#    'suffix(2)': 'It',
#    'suffix(3)': 'It'},
#   'PPS'),
#  ({'prev-word': 'It', 'suffix(1)': 'd', 'suffix(2)': 'ed', 'suffix(3)': 'ded'},
#   'VBD'),
#  ({'prev-word': 'recommended',
#    'suffix(1)': 't',
#    'suffix(2)': 'at',
#    'suffix(3)': 'hat'},
#   'CS'),
#  ({'prev-word': 'that',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ton'},
#   'NP'),
#  ({'prev-word': 'Fulton',
#    'suffix(1)': 's',
#    'suffix(2)': 'rs',
#    'suffix(3)': 'ors'},
#   'NNS'),
#  ({'prev-word': 'legislators',
#    'suffix(1)': 't',
#    'suffix(2)': 'ct',
#    'suffix(3)': 'act'},
#   'VB'),
#  ({'prev-word': 'act', 'suffix(1)': '`', 'suffix(2)': '``', 'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'o', 'suffix(2)': 'to', 'suffix(3)': 'to'},
#   'TO'),
#  ({'prev-word': 'to', 'suffix(1)': 'e', 'suffix(2)': 've', 'suffix(3)': 'ave'},
#   'HV'),
#  ({'prev-word': 'have',
#    'suffix(1)': 'e',
#    'suffix(2)': 'se',
#    'suffix(3)': 'ese'},
#   'DTS'),
#  ({'prev-word': 'these',
#    'suffix(1)': 's',
#    'suffix(2)': 'ws',
#    'suffix(3)': 'aws'},
#   'NNS'),
#  ({'prev-word': 'laws',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ied'},
#   'VBN'),
#  ({'prev-word': 'studied',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'sed'},
#   'VBN'),
#  ({'prev-word': 'revised',
#    'suffix(1)': 'o',
#    'suffix(2)': 'to',
#    'suffix(3)': 'to'},
#   'IN'),
#  ({'prev-word': 'to', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'end'},
#   'NN'),
#  ({'prev-word': 'end', 'suffix(1)': 'f', 'suffix(2)': 'of', 'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'g', 'suffix(2)': 'ng', 'suffix(3)': 'ing'},
#   'VBG'),
#  ({'prev-word': 'modernizing',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 'g',
#    'suffix(2)': 'ng',
#    'suffix(3)': 'ing'},
#   'VBG'),
#  ({'prev-word': 'improving',
#    'suffix(1)': 'm',
#    'suffix(2)': 'em',
#    'suffix(3)': 'hem'},
#   'PPO'),
#  ({'prev-word': 'them',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'JJ'),
#  ({'prev-word': 'grand',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ury'},
#   'NN'),
#  ({'prev-word': 'jury',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ted'},
#   'VBD'),
#  ({'prev-word': 'commented',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'on'},
#   'IN'),
#  ({'prev-word': 'on', 'suffix(1)': 'a', 'suffix(2)': 'a', 'suffix(3)': 'a'},
#   'AT'),
#  ({'prev-word': 'a', 'suffix(1)': 'r', 'suffix(2)': 'er', 'suffix(3)': 'ber'},
#   'NN'),
#  ({'prev-word': 'number',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'r', 'suffix(2)': 'er', 'suffix(3)': 'her'},
#   'AP'),
#  ({'prev-word': 'other',
#    'suffix(1)': 's',
#    'suffix(2)': 'cs',
#    'suffix(3)': 'ics'},
#   'NNS'),
#  ({'prev-word': 'topics',
#    'suffix(1)': ',',
#    'suffix(2)': ',',
#    'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'g', 'suffix(2)': 'ng', 'suffix(3)': 'ong'},
#   'IN'),
#  ({'prev-word': 'among',
#    'suffix(1)': 'm',
#    'suffix(2)': 'em',
#    'suffix(3)': 'hem'},
#   'PPO'),
#  ({'prev-word': 'them',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'a',
#    'suffix(2)': 'ta',
#    'suffix(3)': 'nta'},
#   'NP'),
#  ({'prev-word': 'Atlanta',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ton'},
#   'NP-TL'),
#  ({'prev-word': 'Fulton',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ty',
#    'suffix(3)': 'nty'},
#   'NN-TL'),
#  ({'prev-word': 'County',
#    'suffix(1)': 'g',
#    'suffix(2)': 'ng',
#    'suffix(3)': 'ing'},
#   'VBG'),
#  ({'prev-word': 'purchasing',
#    'suffix(1)': 's',
#    'suffix(2)': 'ts',
#    'suffix(3)': 'nts'},
#   'NNS'),
#  ({'prev-word': 'departments',
#    'suffix(1)': 'h',
#    'suffix(2)': 'ch',
#    'suffix(3)': 'ich'},
#   'WDT'),
#  ({'prev-word': 'which',
#    'suffix(1)': 't',
#    'suffix(2)': 'it',
#    'suffix(3)': 'it'},
#   'PPS'),
#  ({'prev-word': 'it', 'suffix(1)': 'd', 'suffix(2)': 'id', 'suffix(3)': 'aid'},
#   'VBD'),
#  ({'prev-word': 'said',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'e', 'suffix(2)': 're', 'suffix(3)': 'are'},
#   'BER'),
#  ({'prev-word': 'are',
#    'suffix(1)': 'l',
#    'suffix(2)': 'll',
#    'suffix(3)': 'ell'},
#   'QL'),
#  ({'prev-word': 'well',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ted'},
#   'VBN'),
#  ({'prev-word': 'operated',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 'w',
#    'suffix(2)': 'ow',
#    'suffix(3)': 'low'},
#   'VB'),
#  ({'prev-word': 'follow',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ly',
#    'suffix(3)': 'lly'},
#   'RB'),
#  ({'prev-word': 'generally',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ted'},
#   'VBN'),
#  ({'prev-word': 'accepted',
#    'suffix(1)': 's',
#    'suffix(2)': 'es',
#    'suffix(3)': 'ces'},
#   'NNS'),
#  ({'prev-word': 'practices',
#    'suffix(1)': 'h',
#    'suffix(2)': 'ch',
#    'suffix(3)': 'ich'},
#   'WDT'),
#  ({'prev-word': 'which',
#    'suffix(1)': 'e',
#    'suffix(2)': 're',
#    'suffix(3)': 'ure'},
#   'VB'),
#  ({'prev-word': 'inure',
#    'suffix(1)': 'o',
#    'suffix(2)': 'to',
#    'suffix(3)': 'to'},
#   'IN'),
#  ({'prev-word': 'to', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 't',
#    'suffix(2)': 'st',
#    'suffix(3)': 'est'},
#   'JJT'),
#  ({'prev-word': 'best',
#    'suffix(1)': 't',
#    'suffix(2)': 'st',
#    'suffix(3)': 'est'},
#   'NN'),
#  ({'prev-word': 'interest',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'h', 'suffix(2)': 'th', 'suffix(3)': 'oth'},
#   'ABX'),
#  ({'prev-word': 'both',
#    'suffix(1)': 's',
#    'suffix(2)': 'ts',
#    'suffix(3)': 'nts'},
#   'NNS'),
#  ({'prev-word': 'governments',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'r',
#    'suffix(2)': 'er',
#    'suffix(3)': 'ger'},
#   'NN-HL'),
#  ({'prev-word': 'Merger',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'sed'},
#   'VBN-HL'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'r',
#    'suffix(2)': 'er',
#    'suffix(3)': 'ver'},
#   'WRB'),
#  ({'prev-word': 'However',
#    'suffix(1)': ',',
#    'suffix(2)': ',',
#    'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ury'},
#   'NN'),
#  ({'prev-word': 'jury',
#    'suffix(1)': 'd',
#    'suffix(2)': 'id',
#    'suffix(3)': 'aid'},
#   'VBD'),
#  ({'prev-word': 'said',
#    'suffix(1)': 't',
#    'suffix(2)': 'it',
#    'suffix(3)': 'it'},
#   'PPS'),
#  ({'prev-word': 'it', 'suffix(1)': 's', 'suffix(2)': 'es', 'suffix(3)': 'ves'},
#   'VBZ'),
#  ({'prev-word': 'believes',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'e', 'suffix(2)': 'se', 'suffix(3)': 'ese'},
#   'DTS'),
#  ({'prev-word': 'these',
#    'suffix(1)': 'o',
#    'suffix(2)': 'wo',
#    'suffix(3)': 'two'},
#   'CD'),
#  ({'prev-word': 'two',
#    'suffix(1)': 's',
#    'suffix(2)': 'es',
#    'suffix(3)': 'ces'},
#   'NNS'),
#  ({'prev-word': 'offices',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ld',
#    'suffix(3)': 'uld'},
#   'MD'),
#  ({'prev-word': 'should',
#    'suffix(1)': 'e',
#    'suffix(2)': 'be',
#    'suffix(3)': 'be'},
#   'BE'),
#  ({'prev-word': 'be', 'suffix(1)': 'd', 'suffix(2)': 'ed', 'suffix(3)': 'ned'},
#   'VBN'),
#  ({'prev-word': 'combined',
#    'suffix(1)': 'o',
#    'suffix(2)': 'to',
#    'suffix(3)': 'to'},
#   'TO'),
#  ({'prev-word': 'to', 'suffix(1)': 'e', 'suffix(2)': 've', 'suffix(3)': 'eve'},
#   'VB'),
#  ({'prev-word': 'achieve',
#    'suffix(1)': 'r',
#    'suffix(2)': 'er',
#    'suffix(3)': 'ter'},
#   'JJR'),
#  ({'prev-word': 'greater',
#    'suffix(1)': 'y',
#    'suffix(2)': 'cy',
#    'suffix(3)': 'ncy'},
#   'NN'),
#  ({'prev-word': 'efficiency',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ce',
#    'suffix(3)': 'uce'},
#   'VB'),
#  ({'prev-word': 'reduce',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 't',
#    'suffix(2)': 'st',
#    'suffix(3)': 'ost'},
#   'NN'),
#  ({'prev-word': 'cost',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'administration',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ty',
#    'suffix(3)': 'ity'},
#   'NN-TL'),
#  ({'prev-word': 'City',
#    'suffix(1)': 'g',
#    'suffix(2)': 'ng',
#    'suffix(3)': 'ing'},
#   'VBG-TL'),
#  ({'prev-word': 'Purchasing',
#    'suffix(1)': 't',
#    'suffix(2)': 'nt',
#    'suffix(3)': 'ent'},
#   'NN-TL'),
#  ({'prev-word': 'Department',
#    'suffix(1)': ',',
#    'suffix(2)': ',',
#    'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ury'},
#   'NN'),
#  ({'prev-word': 'jury',
#    'suffix(1)': 'd',
#    'suffix(2)': 'id',
#    'suffix(3)': 'aid'},
#   'VBD'),
#  ({'prev-word': 'said', 'suffix(1)': ',', 'suffix(2)': ',', 'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': '`', 'suffix(2)': '``', 'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 's', 'suffix(2)': 'is', 'suffix(3)': 'is'},
#   'BEZ'),
#  ({'prev-word': 'is', 'suffix(1)': 'g', 'suffix(2)': 'ng', 'suffix(3)': 'ing'},
#   'VBG'),
#  ({'prev-word': 'lacking',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'd', 'suffix(2)': 'ed', 'suffix(3)': 'ced'},
#   'VBN'),
#  ({'prev-word': 'experienced',
#    'suffix(1)': 'l',
#    'suffix(2)': 'al',
#    'suffix(3)': 'cal'},
#   'JJ'),
#  ({'prev-word': 'clerical',
#    'suffix(1)': 'l',
#    'suffix(2)': 'el',
#    'suffix(3)': 'nel'},
#   'NNS'),
#  ({'prev-word': 'personnel',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'as'},
#   'CS'),
#  ({'prev-word': 'as', 'suffix(1)': 'a', 'suffix(2)': 'a', 'suffix(3)': 'a'},
#   'AT'),
#  ({'prev-word': 'a', 'suffix(1)': 't', 'suffix(2)': 'lt', 'suffix(3)': 'ult'},
#   'NN'),
#  ({'prev-word': 'result',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'y', 'suffix(2)': 'ty', 'suffix(3)': 'ity'},
#   'NN'),
#  ({'prev-word': 'city',
#    'suffix(1)': 'l',
#    'suffix(2)': 'el',
#    'suffix(3)': 'nel'},
#   'NNS'),
#  ({'prev-word': 'personnel',
#    'suffix(1)': 's',
#    'suffix(2)': 'es',
#    'suffix(3)': 'ies'},
#   'NNS'),
#  ({'prev-word': 'policies',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 't',
#    'suffix(2)': 'It',
#    'suffix(3)': 'It'},
#   'PPS'),
#  ({'prev-word': 'It', 'suffix(1)': 'd', 'suffix(2)': 'ed', 'suffix(3)': 'ged'},
#   'VBD'),
#  ({'prev-word': 'urged',
#    'suffix(1)': 't',
#    'suffix(2)': 'at',
#    'suffix(3)': 'hat'},
#   'CS'),
#  ({'prev-word': 'that',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ty',
#    'suffix(3)': 'ity'},
#   'NN'),
#  ({'prev-word': 'city',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'e', 'suffix(2)': 'ke', 'suffix(3)': 'ake'},
#   'VB'),
#  ({'prev-word': 'take',
#    'suffix(1)': 's',
#    'suffix(2)': 'ps',
#    'suffix(3)': 'eps'},
#   'NNS'),
#  ({'prev-word': 'steps',
#    'suffix(1)': 'o',
#    'suffix(2)': 'to',
#    'suffix(3)': 'to'},
#   'TO'),
#  ({'prev-word': 'to', 'suffix(1)': 'y', 'suffix(2)': 'dy', 'suffix(3)': 'edy'},
#   'VB'),
#  ({'prev-word': 'remedy',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': 's', 'suffix(2)': 'is', 'suffix(3)': 'his'},
#   'DT'),
#  ({'prev-word': 'this',
#    'suffix(1)': 'm',
#    'suffix(2)': 'em',
#    'suffix(3)': 'lem'},
#   'NN'),
#  ({'prev-word': 'problem',
#    'suffix(1)': '.',
#    'suffix(2)': '.',
#    'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'Implementation',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 's', 'suffix(2)': "'s", 'suffix(3)': "a's"},
#   'NP$'),
#  ({'prev-word': "Georgia's",
#    'suffix(1)': 'e',
#    'suffix(2)': 'le',
#    'suffix(3)': 'ile'},
#   'NN'),
#  ({'prev-word': 'automobile',
#    'suffix(1)': 'e',
#    'suffix(2)': 'le',
#    'suffix(3)': 'tle'},
#   'NN'),
#  ({'prev-word': 'title',
#    'suffix(1)': 'w',
#    'suffix(2)': 'aw',
#    'suffix(3)': 'law'},
#   'NN'),
#  ({'prev-word': 'law',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'was'},
#   'BEDZ'),
#  ({'prev-word': 'was',
#    'suffix(1)': 'o',
#    'suffix(2)': 'so',
#    'suffix(3)': 'lso'},
#   'RB'),
#  ({'prev-word': 'also',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ded'},
#   'VBN'),
#  ({'prev-word': 'recommended',
#    'suffix(1)': 'y',
#    'suffix(2)': 'by',
#    'suffix(3)': 'by'},
#   'IN'),
#  ({'prev-word': 'by', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'g',
#    'suffix(2)': 'ng',
#    'suffix(3)': 'ing'},
#   'JJ'),
#  ({'prev-word': 'outgoing',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ury'},
#   'NN'),
#  ({'prev-word': 'jury', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 't',
#    'suffix(2)': 'It',
#    'suffix(3)': 'It'},
#   'PPS'),
#  ({'prev-word': 'It', 'suffix(1)': 'd', 'suffix(2)': 'ed', 'suffix(3)': 'ged'},
#   'VBD'),
#  ({'prev-word': 'urged',
#    'suffix(1)': 't',
#    'suffix(2)': 'at',
#    'suffix(3)': 'hat'},
#   'CS'),
#  ({'prev-word': 'that',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 't',
#    'suffix(2)': 'xt',
#    'suffix(3)': 'ext'},
#   'AP'),
#  ({'prev-word': 'next',
#    'suffix(1)': 'e',
#    'suffix(2)': 're',
#    'suffix(3)': 'ure'},
#   'NN-TL'),
#  ({'prev-word': 'Legislature',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'e', 'suffix(2)': 'de', 'suffix(3)': 'ide'},
#   'VB'),
#  ({'prev-word': 'provide',
#    'suffix(1)': 'g',
#    'suffix(2)': 'ng',
#    'suffix(3)': 'ing'},
#   'VBG'),
#  ({'prev-word': 'enabling',
#    'suffix(1)': 's',
#    'suffix(2)': 'ds',
#    'suffix(3)': 'nds'},
#   'NNS'),
#  ({'prev-word': 'funds',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 't',
#    'suffix(2)': 'et',
#    'suffix(3)': 'set'},
#   'VB'),
#  ({'prev-word': 're-set',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'e',
#    'suffix(2)': 've',
#    'suffix(3)': 'ive'},
#   'JJ'),
#  ({'prev-word': 'effective',
#    'suffix(1)': 'e',
#    'suffix(2)': 'te',
#    'suffix(3)': 'ate'},
#   'NN'),
#  ({'prev-word': 'date',
#    'suffix(1)': 'o',
#    'suffix(2)': 'so',
#    'suffix(3)': 'so'},
#   'CS'),
#  ({'prev-word': 'so', 'suffix(1)': 't', 'suffix(2)': 'at', 'suffix(3)': 'hat'},
#   'CS'),
#  ({'prev-word': 'that',
#    'suffix(1)': 'n',
#    'suffix(2)': 'an',
#    'suffix(3)': 'an'},
#   'AT'),
#  ({'prev-word': 'an', 'suffix(1)': 'y', 'suffix(2)': 'ly', 'suffix(3)': 'rly'},
#   'JJ'),
#  ({'prev-word': 'orderly',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'implementation',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'w',
#    'suffix(2)': 'aw',
#    'suffix(3)': 'law'},
#   'NN'),
#  ({'prev-word': 'law',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ay',
#    'suffix(3)': 'may'},
#   'MD'),
#  ({'prev-word': 'may', 'suffix(1)': 'e', 'suffix(2)': 'be', 'suffix(3)': 'be'},
#   'BE'),
#  ({'prev-word': 'be', 'suffix(1)': 'd', 'suffix(2)': 'ed', 'suffix(3)': 'ted'},
#   'VBN'),
#  ({'prev-word': 'effected',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'JJ'),
#  ({'prev-word': 'grand',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ury'},
#   'NN'),
#  ({'prev-word': 'jury',
#    'suffix(1)': 'k',
#    'suffix(2)': 'ok',
#    'suffix(3)': 'ook'},
#   'VBD'),
#  ({'prev-word': 'took', 'suffix(1)': 'a', 'suffix(2)': 'a', 'suffix(3)': 'a'},
#   'AT'),
#  ({'prev-word': 'a', 'suffix(1)': 'e', 'suffix(2)': 'pe', 'suffix(3)': 'ipe'},
#   'NN'),
#  ({'prev-word': 'swipe',
#    'suffix(1)': 't',
#    'suffix(2)': 'at',
#    'suffix(3)': 'at'},
#   'IN'),
#  ({'prev-word': 'at', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'e',
#    'suffix(2)': 'te',
#    'suffix(3)': 'ate'},
#   'NN-TL'),
#  ({'prev-word': 'State',
#    'suffix(1)': 'e',
#    'suffix(2)': 're',
#    'suffix(3)': 'are'},
#   'NN-TL'),
#  ({'prev-word': 'Welfare',
#    'suffix(1)': 's',
#    'suffix(2)': "'s",
#    'suffix(3)': "t's"},
#   'NN$-TL'),
#  ({'prev-word': "Department's",
#    'suffix(1)': 'g',
#    'suffix(2)': 'ng',
#    'suffix(3)': 'ing'},
#   'NN'),
#  ({'prev-word': 'handling',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'l', 'suffix(2)': 'al', 'suffix(3)': 'ral'},
#   'JJ'),
#  ({'prev-word': 'federal',
#    'suffix(1)': 's',
#    'suffix(2)': 'ds',
#    'suffix(3)': 'nds'},
#   'NNS'),
#  ({'prev-word': 'funds',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ted'},
#   'VBN'),
#  ({'prev-word': 'granted',
#    'suffix(1)': 'r',
#    'suffix(2)': 'or',
#    'suffix(3)': 'for'},
#   'IN'),
#  ({'prev-word': 'for',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ld',
#    'suffix(3)': 'ild'},
#   'NN'),
#  ({'prev-word': 'child',
#    'suffix(1)': 'e',
#    'suffix(2)': 're',
#    'suffix(3)': 'are'},
#   'NN'),
#  ({'prev-word': 'welfare',
#    'suffix(1)': 's',
#    'suffix(2)': 'es',
#    'suffix(3)': 'ces'},
#   'NNS'),
#  ({'prev-word': 'services',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'r', 'suffix(2)': 'er', 'suffix(3)': 'ter'},
#   'JJ'),
#  ({'prev-word': 'foster',
#    'suffix(1)': 's',
#    'suffix(2)': 'es',
#    'suffix(3)': 'mes'},
#   'NNS'),
#  ({'prev-word': 'homes', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 's', 'suffix(2)': 'is', 'suffix(3)': 'his'},
#   'DT'),
#  ({'prev-word': 'This',
#    'suffix(1)': 's',
#    'suffix(2)': 'is',
#    'suffix(3)': 'is'},
#   'BEZ'),
#  ({'prev-word': 'is', 'suffix(1)': 'e', 'suffix(2)': 'ne', 'suffix(3)': 'one'},
#   'CD'),
#  ({'prev-word': 'one', 'suffix(1)': 'f', 'suffix(2)': 'of', 'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'r',
#    'suffix(2)': 'or',
#    'suffix(3)': 'jor'},
#   'JJ'),
#  ({'prev-word': 'major',
#    'suffix(1)': 's',
#    'suffix(2)': 'ms',
#    'suffix(3)': 'ems'},
#   'NNS'),
#  ({'prev-word': 'items',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ton'},
#   'NP-TL'),
#  ({'prev-word': 'Fulton',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ty',
#    'suffix(3)': 'nty'},
#   'NN-TL'),
#  ({'prev-word': 'County',
#    'suffix(1)': 'l',
#    'suffix(2)': 'al',
#    'suffix(3)': 'ral'},
#   'JJ'),
#  ({'prev-word': 'general',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ce',
#    'suffix(3)': 'nce'},
#   'NN'),
#  ({'prev-word': 'assistance',
#    'suffix(1)': 'm',
#    'suffix(2)': 'am',
#    'suffix(3)': 'ram'},
#   'NN'),
#  ({'prev-word': 'program',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': ',', 'suffix(2)': ',', 'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'ury'},
#   'NN'),
#  ({'prev-word': 'jury',
#    'suffix(1)': 'd',
#    'suffix(2)': 'id',
#    'suffix(3)': 'aid'},
#   'VBD'),
#  ({'prev-word': 'said', 'suffix(1)': ',', 'suffix(2)': ',', 'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 't', 'suffix(2)': 'ut', 'suffix(3)': 'but'},
#   'CC'),
#  ({'prev-word': 'but',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'e',
#    'suffix(2)': 'te',
#    'suffix(3)': 'ate'},
#   'NN-TL'),
#  ({'prev-word': 'State',
#    'suffix(1)': 'e',
#    'suffix(2)': 're',
#    'suffix(3)': 'are'},
#   'NN-TL'),
#  ({'prev-word': 'Welfare',
#    'suffix(1)': 't',
#    'suffix(2)': 'nt',
#    'suffix(3)': 'ent'},
#   'NN-TL'),
#  ({'prev-word': 'Department',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 's', 'suffix(2)': 'as', 'suffix(3)': 'has'},
#   'HVZ'),
#  ({'prev-word': 'has',
#    'suffix(1)': 'n',
#    'suffix(2)': 'en',
#    'suffix(3)': 'een'},
#   'VBN'),
#  ({'prev-word': 'seen',
#    'suffix(1)': 't',
#    'suffix(2)': 'it',
#    'suffix(3)': 'fit'},
#   'JJ'),
#  ({'prev-word': 'fit', 'suffix(1)': 'o', 'suffix(2)': 'to', 'suffix(3)': 'to'},
#   'TO'),
#  ({'prev-word': 'to', 'suffix(1)': 'e', 'suffix(2)': 'te', 'suffix(3)': 'ute'},
#   'VB'),
#  ({'prev-word': 'distribute',
#    'suffix(1)': 'e',
#    'suffix(2)': 'se',
#    'suffix(3)': 'ese'},
#   'DTS'),
#  ({'prev-word': 'these',
#    'suffix(1)': 's',
#    'suffix(2)': 'ds',
#    'suffix(3)': 'nds'},
#   'NNS'),
#  ({'prev-word': 'funds',
#    'suffix(1)': 'h',
#    'suffix(2)': 'gh',
#    'suffix(3)': 'ugh'},
#   'IN'),
#  ({'prev-word': 'through',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'e',
#    'suffix(2)': 're',
#    'suffix(3)': 'are'},
#   'NN'),
#  ({'prev-word': 'welfare',
#    'suffix(1)': 's',
#    'suffix(2)': 'ts',
#    'suffix(3)': 'nts'},
#   'NNS'),
#  ({'prev-word': 'departments',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'l', 'suffix(2)': 'll', 'suffix(3)': 'all'},
#   'ABN'),
#  ({'prev-word': 'all',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 's',
#    'suffix(2)': 'es',
#    'suffix(3)': 'ies'},
#   'NNS'),
#  ({'prev-word': 'counties',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'e',
#    'suffix(2)': 'te',
#    'suffix(3)': 'ate'},
#   'NN'),
#  ({'prev-word': 'state',
#    'suffix(1)': 'h',
#    'suffix(2)': 'th',
#    'suffix(3)': 'ith'},
#   'IN'),
#  ({'prev-word': 'with',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'exception',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ton'},
#   'NP-TL'),
#  ({'prev-word': 'Fulton',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ty',
#    'suffix(3)': 'nty'},
#   'NN-TL'),
#  ({'prev-word': 'County',
#    'suffix(1)': ',',
#    'suffix(2)': ',',
#    'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'h', 'suffix(2)': 'ch', 'suffix(3)': 'ich'},
#   'WDT'),
#  ({'prev-word': 'which',
#    'suffix(1)': 's',
#    'suffix(2)': 'es',
#    'suffix(3)': 'ves'},
#   'VBZ'),
#  ({'prev-word': 'receives',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ne',
#    'suffix(3)': 'one'},
#   'PN'),
#  ({'prev-word': 'none',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 's', 'suffix(2)': 'is', 'suffix(3)': 'his'},
#   'DT'),
#  ({'prev-word': 'this',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ey',
#    'suffix(3)': 'ney'},
#   'NN'),
#  ({'prev-word': 'money', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 's',
#    'suffix(2)': 'rs',
#    'suffix(3)': 'ors'},
#   'NNS'),
#  ({'prev-word': 'jurors',
#    'suffix(1)': 'd',
#    'suffix(2)': 'id',
#    'suffix(3)': 'aid'},
#   'VBD'),
#  ({'prev-word': 'said',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ey',
#    'suffix(3)': 'hey'},
#   'PPSS'),
#  ({'prev-word': 'they',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ze',
#    'suffix(3)': 'ize'},
#   'VB'),
#  ({'prev-word': 'realize',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'a', 'suffix(2)': 'a', 'suffix(3)': 'a'},
#   'AT'),
#  ({'prev-word': 'a', 'suffix(1)': 'e', 'suffix(2)': 'te', 'suffix(3)': 'ate'},
#   'JJ'),
#  ({'prev-word': 'proportionate',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'distribution',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'e', 'suffix(2)': 'se', 'suffix(3)': 'ese'},
#   'DTS'),
#  ({'prev-word': 'these',
#    'suffix(1)': 's',
#    'suffix(2)': 'ds',
#    'suffix(3)': 'nds'},
#   'NNS'),
#  ({'prev-word': 'funds',
#    'suffix(1)': 't',
#    'suffix(2)': 'ht',
#    'suffix(3)': 'ght'},
#   'MD'),
#  ({'prev-word': 'might',
#    'suffix(1)': 'e',
#    'suffix(2)': 'le',
#    'suffix(3)': 'ble'},
#   'VB'),
#  ({'prev-word': 'disable',
#    'suffix(1)': 's',
#    'suffix(2)': 'is',
#    'suffix(3)': 'his'},
#   'DT'),
#  ({'prev-word': 'this',
#    'suffix(1)': 'm',
#    'suffix(2)': 'am',
#    'suffix(3)': 'ram'},
#   'NN'),
#  ({'prev-word': 'program',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'r', 'suffix(2)': 'ur', 'suffix(3)': 'our'},
#   'PP$'),
#  ({'prev-word': 'our',
#    'suffix(1)': 's',
#    'suffix(2)': 'ss',
#    'suffix(3)': 'ess'},
#   'QL'),
#  ({'prev-word': 'less',
#    'suffix(1)': 's',
#    'suffix(2)': 'us',
#    'suffix(3)': 'ous'},
#   'JJ'),
#  ({'prev-word': 'populous',
#    'suffix(1)': 's',
#    'suffix(2)': 'es',
#    'suffix(3)': 'ies'},
#   'NNS'),
#  ({'prev-word': 'counties',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 's',
#    'suffix(2)': 'ss',
#    'suffix(3)': 'ess'},
#   'RB'),
#  ({'prev-word': 'Nevertheless',
#    'suffix(1)': ',',
#    'suffix(2)': ',',
#    'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': '`', 'suffix(2)': '``', 'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'e', 'suffix(2)': 'we', 'suffix(3)': 'we'},
#   'PPSS'),
#  ({'prev-word': 'we', 'suffix(1)': 'l', 'suffix(2)': 'el', 'suffix(3)': 'eel'},
#   'VB'),
#  ({'prev-word': 'feel',
#    'suffix(1)': 't',
#    'suffix(2)': 'at',
#    'suffix(3)': 'hat'},
#   'CS'),
#  ({'prev-word': 'that',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'e',
#    'suffix(2)': 're',
#    'suffix(3)': 'ure'},
#   'NN'),
#  ({'prev-word': 'future',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ton'},
#   'NP-TL'),
#  ({'prev-word': 'Fulton',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ty',
#    'suffix(3)': 'nty'},
#   'NN-TL'),
#  ({'prev-word': 'County',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ld',
#    'suffix(3)': 'uld'},
#   'MD'),
#  ({'prev-word': 'should',
#    'suffix(1)': 'e',
#    'suffix(2)': 've',
#    'suffix(3)': 'ive'},
#   'VB'),
#  ({'prev-word': 'receive',
#    'suffix(1)': 'e',
#    'suffix(2)': 'me',
#    'suffix(3)': 'ome'},
#   'DTI'),
#  ({'prev-word': 'some',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'portion',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'e', 'suffix(2)': 'se', 'suffix(3)': 'ese'},
#   'DTS'),
#  ({'prev-word': 'these',
#    'suffix(1)': 'e',
#    'suffix(2)': 'le',
#    'suffix(3)': 'ble'},
#   'JJ'),
#  ({'prev-word': 'available',
#    'suffix(1)': 's',
#    'suffix(2)': 'ds',
#    'suffix(3)': 'nds'},
#   'NNS'),
#  ({'prev-word': 'funds',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': ',', 'suffix(2)': ',', 'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 's',
#    'suffix(2)': 'rs',
#    'suffix(3)': 'ors'},
#   'NNS'),
#  ({'prev-word': 'jurors',
#    'suffix(1)': 'd',
#    'suffix(2)': 'id',
#    'suffix(3)': 'aid'},
#   'VBD'),
#  ({'prev-word': 'said', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': '`',
#    'suffix(2)': '``',
#    'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'e', 'suffix(2)': 're', 'suffix(3)': 'ure'},
#   'NN'),
#  ({'prev-word': 'Failure',
#    'suffix(1)': 'o',
#    'suffix(2)': 'to',
#    'suffix(3)': 'to'},
#   'TO'),
#  ({'prev-word': 'to', 'suffix(1)': 'o', 'suffix(2)': 'do', 'suffix(3)': 'do'},
#   'DO'),
#  ({'prev-word': 'do', 'suffix(1)': 's', 'suffix(2)': 'is', 'suffix(3)': 'his'},
#   'DT'),
#  ({'prev-word': 'this',
#    'suffix(1)': 'l',
#    'suffix(2)': 'll',
#    'suffix(3)': 'ill'},
#   'MD'),
#  ({'prev-word': 'will',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ue',
#    'suffix(3)': 'nue'},
#   'VB'),
#  ({'prev-word': 'continue',
#    'suffix(1)': 'o',
#    'suffix(2)': 'to',
#    'suffix(3)': 'to'},
#   'TO'),
#  ({'prev-word': 'to', 'suffix(1)': 'e', 'suffix(2)': 'ce', 'suffix(3)': 'ace'},
#   'VB'),
#  ({'prev-word': 'place', 'suffix(1)': 'a', 'suffix(2)': 'a', 'suffix(3)': 'a'},
#   'AT'),
#  ({'prev-word': 'a', 'suffix(1)': 'e', 'suffix(2)': 'te', 'suffix(3)': 'ate'},
#   'JJ'),
#  ({'prev-word': 'disproportionate',
#    'suffix(1)': 'n',
#    'suffix(2)': 'en',
#    'suffix(3)': 'den'},
#   'NN'),
#  ({'prev-word': 'burden',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'on'},
#   'IN'),
#  ({'prev-word': 'on', 'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ton'},
#   'NP'),
#  ({'prev-word': 'Fulton',
#    'suffix(1)': 's',
#    'suffix(2)': 'rs',
#    'suffix(3)': 'ers'},
#   'NNS'),
#  ({'prev-word': 'taxpayers',
#    'suffix(1)': '.',
#    'suffix(2)': '.',
#    'suffix(3)': '.'},
#   '.'),
# ...
#    'suffix(3)': 'een'},
#   'BEN'),
#  ({'prev-word': 'been',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'eed'},
#   'VBN'),
#  ({'prev-word': 'agreed',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'pon'},
#   'RB'),
#  ({'prev-word': 'upon', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'petition',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ted'},
#   'VBD'),
#  ({'prev-word': 'listed',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 's',
#    'suffix(2)': "'s",
#    'suffix(3)': "r's"},
#   'NN$'),
#  ({'prev-word': "mayor's",
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'occupation',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'as'},
#   'CS'),
#  ({'prev-word': 'as', 'suffix(1)': '`', 'suffix(2)': '``', 'suffix(3)': '``'},
#   '``'),
#  ({'prev-word': '``', 'suffix(1)': 'y', 'suffix(2)': 'ey', 'suffix(3)': 'ney'},
#   'NN'),
#  ({'prev-word': 'attorney',
#    'suffix(1)': "'",
#    'suffix(2)': "''",
#    'suffix(3)': "''"},
#   "''"),
#  ({'prev-word': "''", 'suffix(1)': 'd', 'suffix(2)': 'nd', 'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 's',
#    'suffix(2)': 'is',
#    'suffix(3)': 'his'},
#   'PP$'),
#  ({'prev-word': 'his',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ge',
#    'suffix(3)': 'age'},
#   'NN'),
#  ({'prev-word': 'age', 'suffix(1)': 's', 'suffix(2)': 'as', 'suffix(3)': 'as'},
#   'CS'),
#  ({'prev-word': 'as', 'suffix(1)': '1', 'suffix(2)': '71', 'suffix(3)': '71'},
#   'CD'),
#  ({'prev-word': '71', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 't',
#    'suffix(2)': 'It',
#    'suffix(3)': 'It'},
#   'PPS'),
#  ({'prev-word': 'It', 'suffix(1)': 'd', 'suffix(2)': 'ed', 'suffix(3)': 'ted'},
#   'VBD'),
#  ({'prev-word': 'listed',
#    'suffix(1)': 's',
#    'suffix(2)': 'is',
#    'suffix(3)': 'his'},
#   'PP$'),
#  ({'prev-word': 'his',
#    'suffix(1)': 's',
#    'suffix(2)': "'s",
#    'suffix(3)': "e's"},
#   'NN$'),
#  ({'prev-word': "wife's",
#    'suffix(1)': 'e',
#    'suffix(2)': 'ge',
#    'suffix(3)': 'age'},
#   'NN'),
#  ({'prev-word': 'age', 'suffix(1)': 's', 'suffix(2)': 'as', 'suffix(3)': 'as'},
#   'CS'),
#  ({'prev-word': 'as', 'suffix(1)': '4', 'suffix(2)': '74', 'suffix(3)': '74'},
#   'CD'),
#  ({'prev-word': '74', 'suffix(1)': 'd', 'suffix(2)': 'nd', 'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 'e',
#    'suffix(2)': 'ce',
#    'suffix(3)': 'ace'},
#   'NN'),
#  ({'prev-word': 'place',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'h', 'suffix(2)': 'th', 'suffix(3)': 'rth'},
#   'NN'),
#  ({'prev-word': 'birth',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'as'},
#   'CS'),
#  ({'prev-word': 'as', 'suffix(1)': 'a', 'suffix(2)': 'ka', 'suffix(3)': 'ika'},
#   'NP'),
#  ({'prev-word': 'Opelika',
#    'suffix(1)': ',',
#    'suffix(2)': ',',
#    'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': '.', 'suffix(2)': 'a.', 'suffix(3)': 'la.'},
#   'NP'),
#  ({'prev-word': 'Ala.', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'petition',
#    'suffix(1)': 'd',
#    'suffix(2)': 'id',
#    'suffix(3)': 'aid'},
#   'VBD'),
#  ({'prev-word': 'said',
#    'suffix(1)': 't',
#    'suffix(2)': 'at',
#    'suffix(3)': 'hat'},
#   'CS'),
#  ({'prev-word': 'that',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'e',
#    'suffix(2)': 'le',
#    'suffix(3)': 'ple'},
#   'NN'),
#  ({'prev-word': 'couple',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'has'},
#   'HVZ'),
#  ({'prev-word': 'has',
#    'suffix(1)': 't',
#    'suffix(2)': 'ot',
#    'suffix(3)': 'not'},
#   '*'),
#  ({'prev-word': 'not',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ved'},
#   'VBN'),
#  ({'prev-word': 'lived',
#    'suffix(1)': 'r',
#    'suffix(2)': 'er',
#    'suffix(3)': 'her'},
#   'RB'),
#  ({'prev-word': 'together',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'as'},
#   'CS'),
#  ({'prev-word': 'as', 'suffix(1)': 'n', 'suffix(2)': 'an', 'suffix(3)': 'man'},
#   'NN'),
#  ({'prev-word': 'man',
#    'suffix(1)': 'd',
#    'suffix(2)': 'nd',
#    'suffix(3)': 'and'},
#   'CC'),
#  ({'prev-word': 'and',
#    'suffix(1)': 'e',
#    'suffix(2)': 'fe',
#    'suffix(3)': 'ife'},
#   'NN'),
#  ({'prev-word': 'wife',
#    'suffix(1)': 'r',
#    'suffix(2)': 'or',
#    'suffix(3)': 'for'},
#   'IN'),
#  ({'prev-word': 'for',
#    'suffix(1)': 'e',
#    'suffix(2)': 're',
#    'suffix(3)': 'ore'},
#   'AP'),
#  ({'prev-word': 'more',
#    'suffix(1)': 'n',
#    'suffix(2)': 'an',
#    'suffix(3)': 'han'},
#   'IN'),
#  ({'prev-word': 'than', 'suffix(1)': 'a', 'suffix(2)': 'a', 'suffix(3)': 'a'},
#   'AT'),
#  ({'prev-word': 'a', 'suffix(1)': 'r', 'suffix(2)': 'ar', 'suffix(3)': 'ear'},
#   'NN'),
#  ({'prev-word': 'year', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ld',
#    'suffix(3)': 'eld'},
#   'NP'),
#  ({'prev-word': 'Hartsfield',
#    'suffix(1)': 'e',
#    'suffix(2)': 'me',
#    'suffix(3)': 'ome'},
#   'NR'),
#  ({'prev-word': 'home',
#    'suffix(1)': 's',
#    'suffix(2)': 'is',
#    'suffix(3)': 'is'},
#   'BEZ'),
#  ({'prev-word': 'is', 'suffix(1)': 't', 'suffix(2)': 'at', 'suffix(3)': 'at'},
#   'IN'),
#  ({'prev-word': 'at', 'suffix(1)': '7', 'suffix(2)': '37', 'suffix(3)': '637'},
#   'CD'),
#  ({'prev-word': '637', 'suffix(1)': '.', 'suffix(2)': 'E.', 'suffix(3)': 'E.'},
#   'NP'),
#  ({'prev-word': 'E.', 'suffix(1)': 'm', 'suffix(2)': 'am', 'suffix(3)': 'ham'},
#   'NP'),
#  ({'prev-word': 'Pelham',
#    'suffix(1)': '.',
#    'suffix(2)': 'd.',
#    'suffix(3)': 'Rd.'},
#   'NN-TL'),
#  ({'prev-word': 'Rd.', 'suffix(1)': 'j', 'suffix(2)': 'Aj', 'suffix(3)': 'Aj'},
#   'NN'),
#  ({'prev-word': 'Aj', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'y',
#    'suffix(2)': 'ry',
#    'suffix(3)': 'nry'},
#   'NP'),
#  ({'prev-word': 'Henry',
#    'suffix(1)': '.',
#    'suffix(2)': 'L.',
#    'suffix(3)': 'L.'},
#   'NP'),
#  ({'prev-word': 'L.', 'suffix(1)': 'n', 'suffix(2)': 'en', 'suffix(3)': 'den'},
#   'NP'),
#  ({'prev-word': 'Bowden',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'was'},
#   'BEDZ'),
#  ({'prev-word': 'was',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ted'},
#   'VBN'),
#  ({'prev-word': 'listed',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'on'},
#   'IN'),
#  ({'prev-word': 'on', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'petition',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'as'},
#   'CS'),
#  ({'prev-word': 'as', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': 's',
#    'suffix(2)': "'s",
#    'suffix(3)': "r's"},
#   'NN$'),
#  ({'prev-word': "mayor's",
#    'suffix(1)': 'y',
#    'suffix(2)': 'ey',
#    'suffix(3)': 'ney'},
#   'NN'),
#  ({'prev-word': 'attorney',
#    'suffix(1)': '.',
#    'suffix(2)': '.',
#    'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ld',
#    'suffix(3)': 'eld'},
#   'NP'),
#  ({'prev-word': 'Hartsfield',
#    'suffix(1)': 's',
#    'suffix(2)': 'as',
#    'suffix(3)': 'has'},
#   'HVZ'),
#  ({'prev-word': 'has',
#    'suffix(1)': 'n',
#    'suffix(2)': 'en',
#    'suffix(3)': 'een'},
#   'BEN'),
#  ({'prev-word': 'been',
#    'suffix(1)': 'r',
#    'suffix(2)': 'or',
#    'suffix(3)': 'yor'},
#   'NN'),
#  ({'prev-word': 'mayor',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'a', 'suffix(2)': 'ta', 'suffix(3)': 'nta'},
#   'NP'),
#  ({'prev-word': 'Atlanta',
#    'suffix(1)': ',',
#    'suffix(2)': ',',
#    'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'h', 'suffix(2)': 'th', 'suffix(3)': 'ith'},
#   'IN'),
#  ({'prev-word': 'with',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'exception',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'e', 'suffix(2)': 'ne', 'suffix(3)': 'one'},
#   'CD'),
#  ({'prev-word': 'one',
#    'suffix(1)': 'f',
#    'suffix(2)': 'ef',
#    'suffix(3)': 'ief'},
#   'JJ'),
#  ({'prev-word': 'brief',
#    'suffix(1)': 'e',
#    'suffix(2)': 'de',
#    'suffix(3)': 'ude'},
#   'NN'),
#  ({'prev-word': 'interlude',
#    'suffix(1)': ',',
#    'suffix(2)': ',',
#    'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'e', 'suffix(2)': 'ce', 'suffix(3)': 'nce'},
#   'IN'),
#  ({'prev-word': 'since',
#    'suffix(1)': '7',
#    'suffix(2)': '37',
#    'suffix(3)': '937'},
#   'CD'),
#  ({'prev-word': '1937', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 's',
#    'suffix(2)': 'is',
#    'suffix(3)': 'His'},
#   'PP$'),
#  ({'prev-word': 'His',
#    'suffix(1)': 'l',
#    'suffix(2)': 'al',
#    'suffix(3)': 'cal'},
#   'JJ'),
#  ({'prev-word': 'political',
#    'suffix(1)': 'r',
#    'suffix(2)': 'er',
#    'suffix(3)': 'eer'},
#   'NN'),
#  ({'prev-word': 'career',
#    'suffix(1)': 's',
#    'suffix(2)': 'es',
#    'suffix(3)': 'oes'},
#   'VBZ'),
#  ({'prev-word': 'goes',
#    'suffix(1)': 'k',
#    'suffix(2)': 'ck',
#    'suffix(3)': 'ack'},
#   'RB'),
#  ({'prev-word': 'back',
#    'suffix(1)': 'o',
#    'suffix(2)': 'to',
#    'suffix(3)': 'to'},
#   'IN'),
#  ({'prev-word': 'to', 'suffix(1)': 's', 'suffix(2)': 'is', 'suffix(3)': 'his'},
#   'PP$'),
#  ({'prev-word': 'his',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'election',
#    'suffix(1)': 'o',
#    'suffix(2)': 'to',
#    'suffix(3)': 'to'},
#   'IN'),
#  ({'prev-word': 'to', 'suffix(1)': 'y', 'suffix(2)': 'ty', 'suffix(3)': 'ity'},
#   'NN'),
#  ({'prev-word': 'city',
#    'suffix(1)': 'l',
#    'suffix(2)': 'il',
#    'suffix(3)': 'cil'},
#   'NN'),
#  ({'prev-word': 'council',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': '3', 'suffix(2)': '23', 'suffix(3)': '923'},
#   'CD'),
#  ({'prev-word': '1923', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'The'},
#   'AT'),
#  ({'prev-word': 'The',
#    'suffix(1)': 's',
#    'suffix(2)': "'s",
#    'suffix(3)': "r's"},
#   'NN$'),
#  ({'prev-word': "mayor's",
#    'suffix(1)': 't',
#    'suffix(2)': 'nt',
#    'suffix(3)': 'ent'},
#   'JJ'),
#  ({'prev-word': 'present',
#    'suffix(1)': 'm',
#    'suffix(2)': 'rm',
#    'suffix(3)': 'erm'},
#   'NN'),
#  ({'prev-word': 'term',
#    'suffix(1)': 'f',
#    'suffix(2)': 'of',
#    'suffix(3)': 'of'},
#   'IN'),
#  ({'prev-word': 'of', 'suffix(1)': 'e', 'suffix(2)': 'ce', 'suffix(3)': 'ice'},
#   'NN'),
#  ({'prev-word': 'office',
#    'suffix(1)': 's',
#    'suffix(2)': 'es',
#    'suffix(3)': 'res'},
#   'VBZ'),
#  ({'prev-word': 'expires',
#    'suffix(1)': '.',
#    'suffix(2)': 'n.',
#    'suffix(3)': 'an.'},
#   'NP'),
#  ({'prev-word': 'Jan.', 'suffix(1)': '1', 'suffix(2)': '1', 'suffix(3)': '1'},
#   'CD'),
#  ({'prev-word': '1', 'suffix(1)': '.', 'suffix(2)': '.', 'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'e',
#    'suffix(2)': 'He',
#    'suffix(3)': 'He'},
#   'PPS'),
#  ({'prev-word': 'He', 'suffix(1)': 'l', 'suffix(2)': 'll', 'suffix(3)': 'ill'},
#   'MD'),
#  ({'prev-word': 'will',
#    'suffix(1)': 'e',
#    'suffix(2)': 'be',
#    'suffix(3)': 'be'},
#   'BE'),
#  ({'prev-word': 'be', 'suffix(1)': 'd', 'suffix(2)': 'ed', 'suffix(3)': 'ded'},
#   'VBN'),
#  ({'prev-word': 'succeeded',
#    'suffix(1)': 'y',
#    'suffix(2)': 'by',
#    'suffix(3)': 'by'},
#   'IN'),
#  ({'prev-word': 'by', 'suffix(1)': 'n', 'suffix(2)': 'an', 'suffix(3)': 'van'},
#   'NP'),
#  ({'prev-word': 'Ivan',
#    'suffix(1)': 'n',
#    'suffix(2)': 'en',
#    'suffix(3)': 'len'},
#   'NP'),
#  ({'prev-word': 'Allen',
#    'suffix(1)': '.',
#    'suffix(2)': 'r.',
#    'suffix(3)': 'Jr.'},
#   'NP'),
#  ({'prev-word': 'Jr.', 'suffix(1)': ',', 'suffix(2)': ',', 'suffix(3)': ','},
#   ','),
#  ({'prev-word': ',', 'suffix(1)': 'o', 'suffix(2)': 'ho', 'suffix(3)': 'who'},
#   'WPS'),
#  ({'prev-word': 'who',
#    'suffix(1)': 'e',
#    'suffix(2)': 'me',
#    'suffix(3)': 'ame'},
#   'VBD'),
#  ({'prev-word': 'became',
#    'suffix(1)': 'a',
#    'suffix(2)': 'a',
#    'suffix(3)': 'a'},
#   'AT'),
#  ({'prev-word': 'a', 'suffix(1)': 'e', 'suffix(2)': 'te', 'suffix(3)': 'ate'},
#   'NN'),
#  ({'prev-word': 'candidate',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': '.',
#    'suffix(2)': 't.',
#    'suffix(3)': 'pt.'},
#   'NP'),
#  ({'prev-word': 'Sept.',
#    'suffix(1)': '3',
#    'suffix(2)': '13',
#    'suffix(3)': '13'},
#   'CD'),
#  ({'prev-word': '13', 'suffix(1)': 'y', 'suffix(2)': 'ry', 'suffix(3)': 'ary'},
#   'NN'),
#  ({'prev-word': 'primary',
#    'suffix(1)': 'r',
#    'suffix(2)': 'er',
#    'suffix(3)': 'ter'},
#   'CS'),
#  ({'prev-word': 'after',
#    'suffix(1)': 'r',
#    'suffix(2)': 'or',
#    'suffix(3)': 'yor'},
#   'NN-TL'),
#  ({'prev-word': 'Mayor',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ld',
#    'suffix(3)': 'eld'},
#   'NP'),
#  ({'prev-word': 'Hartsfield',
#    'suffix(1)': 'd',
#    'suffix(2)': 'ed',
#    'suffix(3)': 'ced'},
#   'VBD'),
#  ({'prev-word': 'announced',
#    'suffix(1)': 't',
#    'suffix(2)': 'at',
#    'suffix(3)': 'hat'},
#   'CS'),
#  ({'prev-word': 'that',
#    'suffix(1)': 'e',
#    'suffix(2)': 'he',
#    'suffix(3)': 'he'},
#   'PPS'),
#  ({'prev-word': 'he', 'suffix(1)': 'd', 'suffix(2)': 'ld', 'suffix(3)': 'uld'},
#   'MD'),
#  ({'prev-word': 'would',
#    'suffix(1)': 't',
#    'suffix(2)': 'ot',
#    'suffix(3)': 'not'},
#   '*'),
#  ({'prev-word': 'not',
#    'suffix(1)': 'n',
#    'suffix(2)': 'un',
#    'suffix(3)': 'run'},
#   'VB'),
#  ({'prev-word': 'run',
#    'suffix(1)': 'r',
#    'suffix(2)': 'or',
#    'suffix(3)': 'for'},
#   'IN'),
#  ({'prev-word': 'for',
#    'suffix(1)': 'n',
#    'suffix(2)': 'on',
#    'suffix(3)': 'ion'},
#   'NN'),
#  ({'prev-word': 'reelection',
#    'suffix(1)': '.',
#    'suffix(2)': '.',
#    'suffix(3)': '.'},
#   '.'),
#  ({'prev-word': '<START>',
#    'suffix(1)': 'a',
#    'suffix(2)': 'ia',
#    'suffix(3)': 'gia'},
#   'NP'),
#  ({'prev-word': 'Georgia',
#    'suffix(1)': 's',
#    'suffix(2)': 'ns',
#    'suffix(3)': 'ans'},
#   'NPS'),
#  ({'prev-word': 'Republicans',
#    'suffix(1)': 'e',
#    'suffix(2)': 're',
#    'suffix(3)': 'are'},
#   'BER'),
#  ({'prev-word': 'are',
#    'suffix(1)': 'g',
#    'suffix(2)': 'ng',
#    'suffix(3)': 'ing'},
#   'VBG'),
#  ({'prev-word': 'getting',
#    'suffix(1)': 'g',
#    'suffix(2)': 'ng',
#    'suffix(3)': 'ong'},
#   'JJ'),
#  ({'prev-word': 'strong',
#    'suffix(1)': 't',
#    'suffix(2)': 'nt',
#    'suffix(3)': 'ent'},
#   'NN'),
#  ({'prev-word': 'encouragement',
#    'suffix(1)': 'o',
#    'suffix(2)': 'to',
#    'suffix(3)': 'to'},
#   'TO'),
#  ({'prev-word': 'to', 'suffix(1)': 'r', 'suffix(2)': 'er', 'suffix(3)': 'ter'},
#   'VB'),
#  ({'prev-word': 'enter', 'suffix(1)': 'a', 'suffix(2)': 'a', 'suffix(3)': 'a'},
#   'AT'),
#  ({'prev-word': 'a', 'suffix(1)': 'e', 'suffix(2)': 'te', 'suffix(3)': 'ate'},
#   'NN'),
#  ({'prev-word': 'candidate',
#    'suffix(1)': 'n',
#    'suffix(2)': 'in',
#    'suffix(3)': 'in'},
#   'IN'),
#  ({'prev-word': 'in', 'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the'},
#   'AT'),
#  ({'prev-word': 'the',
#    'suffix(1)': '2',
#    'suffix(2)': '62',
#    'suffix(3)': '962'},
#   'CD'),
#  ({'prev-word': '1962',
#    'suffix(1)': 's',
#    'suffix(2)': "'s",
#    'suffix(3)': "r's"},
#   'NN$'),
#  ...]

# %%
size = int(len(featuresets)*0.1)
train_set, test_set = featuresets[size:], featuresets[:size]  # 获取训练集和测试集

# %%
# 训练
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# 计算准确度
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.7891596220785678

# %%
# 利用上下文特征相对于DecisionTree中的效果，很明显的提升，但是算法使用的不同，不能直接这样比较。
# 这边主要是了解到了上下文的特征的获取方式。
