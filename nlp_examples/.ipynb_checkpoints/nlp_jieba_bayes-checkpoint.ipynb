# %%
# 关于简单的NLP项目的实例
# 由于数据具有敏感性，所以数据并不上传，主要是其结构的变化。

# %%
# -*- coding:utf-8 -*-

# %%
import os
import xlrd
import numpy as np
import jieba
import jieba.analyse
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
BASEDIR = os.getcwd()

# %%
FILENAME = 'repository.xls'
SHEETNAME = 'main'

# %%
# 加载数据集
def load_data(filename,sheetname):
    '''
    从excel中加载数据集。
    入参：filename:文件名
         sheetname:工作簿名
    返回值：repository 知识库
    '''
    filepath = os.path.join(BASEDIR,filename)
    work_book = xlrd.open_workbook(filename)
    sheet = work_book.sheet_by_name(sheetname)
    row = 1
    col = 4
    repository = {}
    index = 0
    flag = True
    if flag:
        while row < 491:
            while col < 30:
                key = sheet.cell(row,4).value
                if key.strip():
                    text = sheet.cell(row,col).value
                    sub_dict = {}
                    if text.strip():
                        sub_dict['question'] = text.strip()
                        sub_dict['knowledge_id'] = sheet.cell(row,0).value
                        repository[index] = sub_dict
                        index +=1
                if col == 4:
                    col = 7
                col +=1
            col = 4
            row +=1
        return repository

# %%
repository = load_data(FILENAME,SHEETNAME)

# %%
len(repository)
# Out:
# 3568

# %%
# 查看repository的格式和内容
repository[0]
# Out:
# {'knowledge_id': 'A0000', 'question': '通知：Concur App发生故障，登陆提示Error403或错误的公司代码'}

# %%
# 数据预处理
def preprocessing(ques):
    '''
    问题字母小写化,并去除里面的换行符
    '''
    return ques.lower().replace('\n','')

# %%
with open('question.txt','w') as f:
    for k,v in repository.items():
        repository[k]['question'] = preprocessing(repository[k]['question'])
        f.write(repository[k]['question'])
        f.write('\n')

# %%
with open('question.txt','r') as fr:
    contents = fr.read()

# %%
# 分词（ 自定义词汇，停用词表）
# 添加用户自定义词典
jieba.load_userdict('userdict.txt')
# 设置停用词表
jieba.analyse.set_stop_words('stop_words.txt')
# 获取去除停用词的关键词
keywords = jieba.analyse.extract_tags(contents, topK = 2000)
print('Words Number:',len(keywords))
stopwords = open('stop_words.txt').read()
# 分词
with open('segments.txt','w') as fs:
    for k,v in repository.items():
        segments = jieba.cut(repository[k]['question'],cut_all =True)
        for i in segments:
            if i not in stopwords:
                fs.write(i)
                fs.write('\t')
        fs.write('\n')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/w2/qnnfb62x2g760j3nkh9q4ptr0000gn/T/jieba.cache
# Loading model cost 0.681 seconds.
# Prefix dict has been built succesfully.
# Words Number: 1916

# %%
corpus = []
with open('segments.txt','r') as fr:
    for line in fr:
        corpus.append(line)

# %%
corpus[:5]
# Out:
# ['通知\tconcur\tapp\t发生\t故障\t登陆\t提示\terror403\t错误\t公司\t代码\t\n',
#  'concur\tapp\t登陆\t\n',
#  'concur\t手机\t手机端\t登陆\t\n',
#  'concur\t手机\t手机端\t登陆\t403\t报错\t\n',
#  'concur\tapp\t登陆\t提示\t公司\t代码\t不正\t正确\t\n']

# %%
# 三种文本特征提取（TF-IDF/Word2Vec/CountVectorizer）

# %%
# 第一种：TF-IDF值，
# CountVectorizer 构建词频矩阵
# TfidfTransformer 构建tfidf权值计算
# 文本的关键字
# 对应的tfidf矩阵

# %%
# CountVectorizer 构建词频矩阵
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corpus)
print(X[:1,:])
X.shape # 3576个问题*2451个词汇
# Out:
#   (0, 424)	1
#   (0, 533)	1
#   (0, 2364)	1
#   (0, 56)	1
#   (0, 1427)	1
#   (0, 1829)	1
#   (0, 1468)	1
#   (0, 779)	1
#   (0, 19)	1
#   (0, 38)	1
#   (0, 2304)	1
# (3568, 2451)

# %%
# 构建TF-IDF权值计算
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(X)
print(tfidf[:1,:])
print(tfidf.shape)
# Out:
#   (0, 2304)	0.27379809813895223
#   (0, 38)	0.2156030330282288
#   (0, 19)	0.26086682456934407
#   (0, 779)	0.3455812051435754
#   (0, 1468)	0.43244588601264666
#   (0, 1829)	0.20728582808083776
#   (0, 1427)	0.20852868372690628
#   (0, 56)	0.43244588601264666
#   (0, 2364)	0.2880807601116773
#   (0, 533)	0.25746859524213583
#   (0, 424)	0.2851682785551384
# (3568, 2451)
# /Users/zoe/anaconda3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
# 获取词袋模型中的关键词
word = vectorizer.get_feature_names()
# tfidf矩阵
weight = tfidf.toarray()
print(weight.shape)
# Out:
# (3568, 2451)

# %%
np.set_printoptions(threshold=np.inf)
weight[0,2307] # 可以通过验证矩阵中的值来检测
# Out:
# 0.0

# %%
# 构造Y向量
labels = []
for k,v in repository.items():
    labels.append(v['knowledge_id'])
labels = list(set(labels)) #490个label

for k,v in repository.items():
    repository[k]['y_index'] = labels.index(v['knowledge_id'])

Y = np.zeros(X.shape[0])
for k,v in repository.items():
    Y[k] = v['y_index']

# %%
# 建立贝叶斯模型
clf = MultinomialNB(0.1)
# 参数alpha的是平滑因子
clf.fit(weight,Y)
# Out:
# MultinomialNB(alpha=0.1, class_prior=None, fit_prior=True)

# %%
# 获取在训练集上的准确度
def train_accuracy():
    count=0
    correct_count = 0
    for ele in weight:
        train_test_vec = ele.reshape((1,a.shape[0]))  # clf.predict()需要的向量为(1,2451)的形状
        answer = clf.predict(train_test_vec)[0]
        if int(answer)==repository[count]['y_index']:
            correct_count +=1
        count +=1
    # 计算准确度
    accuracy = correct_count/count
    print('Training Accuracy:',accuracy)
train_accuracy()
# Out:
# Training Accuracy: 0.9588004484304933

# %%
# 加载测试集
filename = 'test_data.xlsx'
sheetname = '2834'
def load_test_data(filename,sheetname):
    work_book = xlrd.open_workbook(filename)
    sheet = work_book.sheet_by_name(sheetname)
    row = 1
    col = 1
    testset = {}
    index = 0
    while row < 2385:
        key = sheet.cell(row,col).value
        if isinstance(key,str):  
            if key.strip():
                text = sheet.cell(row,col).value
                sub_dict = {}
                if text.strip():
                    sub_dict['question'] = text.strip() if isinstance(text,str) else str(text)
                    sub_dict['knowledge_id'] = sheet.cell(row,col+1).value
                    testset[index] = sub_dict
                    index +=1
        row +=1
    return testset
testset = load_test_data(filename, sheetname)

# %%
# 预处理
for k,v in testset.items():
    testset[k]['question'] = preprocessing(v['question'])
# 用自定义词库和中止词等，进行分词并向量化。
# Out:
# {0: {'knowledge_id': 'C0003', 'question': 'password怎么使用'},
#  1: {'knowledge_id': 'C0001', 'question': '账号能能重置吗'},
#  2: {'knowledge_id': 'J0001', 'question': '您好！能发我下国旅运通订票网址吗？'},
#  3: {'knowledge_id': 'J0001', 'question': '差旅预定系统的网址有么'},
#  4: {'knowledge_id': 'I0001', 'question': '掌上az的下载链接可以给我一下么？'},
#  5: {'knowledge_id': 'G0066', 'question': '你好，现在活动关闭，讲者协议第一张需要重新打印。如何处理'},
#  6: {'knowledge_id': 'D0004', 'question': '您好，有没有阿凡达网页版链接？'},
#  7: {'knowledge_id': 'A0110', 'question': '7575电话'},
#  8: {'knowledge_id': 'A0039', 'question': '怎么联系上扫描中心'},
#  9: {'knowledge_id': 'H0001', 'question': '澳门年会'},
#  10: {'knowledge_id': 'H0001', 'question': '年会议程'},
#  11: {'knowledge_id': 'D0014',
#   'question': '请把q4季度3k考试?ria-普米克令舒+信必可的考试重新推送给我一下可以吗'},
#  12: {'knowledge_id': 'D0016', 'question': '只收到了课程过期的邮件啊'},
#  13: {'knowledge_id': 'E0022', 'question': '嫌疑拜访比例不能超过多少？'},
#  14: {'knowledge_id': 'E0001', 'question': 'concur的公司代码是多少？谢谢'},
#  15: {'knowledge_id': 'E0022', 'question': '请问嫌疑拜访比例不能超过多少？'},
#  16: {'knowledge_id': 'A0047', 'question': '住宿内部订单号'},
#  17: {'knowledge_id': 'A0047', 'question': '你好，请问核心医院团队公司内部培训的住宿费用是订单号是多少'},
#  18: {'knowledge_id': 'I0001', 'question': '掌上az'},
#  19: {'knowledge_id': 'A0065', 'question': '手机登录concur，公司sso代码是多少？'},
#  20: {'knowledge_id': 'J0001', 'question': '差旅系统 登陆'},
#  21: {'knowledge_id': 'A0077', 'question': 'esm活动添加医疗群怎么加'},
#  22: {'knowledge_id': 'A0078', 'question': 'esm活动，参加者需要添加自己吗'},
#  23: {'knowledge_id': 'H0001', 'question': '年会怎么安排的'},
#  24: {'knowledge_id': 'A0099', 'question': '入住的不是协议酒店'},
#  25: {'knowledge_id': 'A0086', 'question': '亲，出差住宿，费用类型填什么'},
#  26: {'knowledge_id': 'C0003', 'question': '域名选择哪一个'},
#  27: {'knowledge_id': 'E0029', 'question': '登录veeva 一直提示身份验证失败？'},
#  28: {'knowledge_id': 'G0067', 'question': 'esm登录不了'},
#  29: {'knowledge_id': 'A0010', 'question': '会议concur编号'},
#  30: {'knowledge_id': 'A0010', 'question': '您好，易活动会议编号多久能导入concur里'},
#  31: {'knowledge_id': 'G0052', 'question': '讲者目标医院更改'},
#  32: {'knowledge_id': 'A0010', 'question': '活动号还没录入怎么办呢，？'},
#  33: {'knowledge_id': 'A0039', 'question': '财务知识懂嘛'},
#  34: {'knowledge_id': 'D0012', 'question': '我的pad不能下载阿凡达'},
#  35: {'knowledge_id': 'A0074', 'question': '打印报销单封面点击后一直是正在加载'},
#  36: {'knowledge_id': 'A0010', 'question': 'concer中找不到活动号'},
#  37: {'knowledge_id': 'A0010',
#   'question': '您好，我的活动关闭后，concer上的活动号一直没有出来，怎么办？'},
#  38: {'knowledge_id': 'C0001', 'question': 'knft737 密码登入'},
#  39: {'knowledge_id': 'D0012', 'question': '下载不了阿凡达'},
#  40: {'knowledge_id': 'I0001', 'question': '你好，帮我推送一下掌上az链接下载'},
#  41: {'knowledge_id': 'C0001', 'question': '你好，麻烦给我重置下密码'},
#  42: {'knowledge_id': 'E0024', 'question': '我的lcustomer客户管理系统里面没有客户？'},
#  43: {'knowledge_id': 'G0075', 'question': 'esm网页版'},
#  44: {'knowledge_id': 'C0001', 'question': '你好，k账号密码过期。你这可以帮忙修改吗？'},
#  45: {'knowledge_id': 'E0024', 'question': '你好，我的客户服务管理系统没有客户'},
#  46: {'knowledge_id': 'D0004', 'question': '阿凡达的网站'},
#  47: {'knowledge_id': 'G0036',
#   'question': '您好，请问我会议是下午5点半的，结果关闭活动才发现当初申请成上午5点半的呢？你们后台能帮我更改时间吗'},
#  48: {'knowledge_id': 'I0001', 'question': '我想下载掌上az'},
#  49: {'knowledge_id': 'A0066', 'question': '公司代码'},
#  50: {'knowledge_id': 'C0001', 'question': '密码过期'},
#  51: {'knowledge_id': 'D0012', 'question': '如下载不了阿凡达'},
#  52: {'knowledge_id': 'I0001', 'question': '你好，有没有掌上az的下载二维码'},
#  53: {'knowledge_id': 'D0006', 'question': '3k考试今天结束了吗'},
#  54: {'knowledge_id': 'D0001', 'question': '怎么安装？'},
#  55: {'knowledge_id': 'E0024', 'question': '添加客户'},
#  56: {'knowledge_id': 'I0001', 'question': '登陆掌上az'},
#  57: {'knowledge_id': 'C0001', 'question': '你好，我的密码过期了'},
#  58: {'knowledge_id': 'A0013', 'question': 'concur报销系统未找到参加者'},
#  59: {'knowledge_id': 'E0001', 'question': '你好，为什么我的医院和产品是0呢？'},
#  60: {'knowledge_id': 'E0039', 'question': '辅导报告确认'},
#  61: {'knowledge_id': 'C0003', 'question': '您好，请帮我修改登录密码'},
#  62: {'knowledge_id': 'A0066', 'question': 'concur企业代码'},
#  63: {'knowledge_id': 'I0001', 'question': '如何安装掌上az'},
#  64: {'knowledge_id': 'C0001', 'question': '我的password过期了，帮忙更新一下吧'},
#  65: {'knowledge_id': 'C0001', 'question': '你好，password过期了，能帮忙更新一个么'},
#  66: {'knowledge_id': 'C0001', 'question': '更改密码'},
#  67: {'knowledge_id': 'C0001', 'question': '密码忘记了'},
#  68: {'knowledge_id': 'A0039', 'question': '审计中心电话'},
#  69: {'knowledge_id': 'C0001', 'question': '你好我的密码过期了'},
#  70: {'knowledge_id': 'E0005', 'question': '我的veeva系统上不去'},
#  71: {'knowledge_id': 'G0075', 'question': '您好！我想请问ems 网页版网址能发我下吗'},
#  72: {'knowledge_id': 'I0001', 'question': '掌上az进不去'},
#  73: {'knowledge_id': 'C0001', 'question': '您好，我重置的密码不正确'},
#  74: {'knowledge_id': 'C0001', 'question': '密码过期怎么办'},
#  75: {'knowledge_id': 'C0003', 'question': '你好，密码过期，登陆不了了'},
#  76: {'knowledge_id': 'C0001', 'question': '我的密码过期 k账号kprd920'},
#  77: {'knowledge_id': 'A0010',
#   'question': '你好！我的活动14号已经关闭了，到时活动编码还没有导入报销系统里？'},
#  78: {'knowledge_id': 'E0029', 'question': '更新显示同步失败'},
#  79: {'knowledge_id': 'E0002', 'question': '我这边crm上不了'},
#  80: {'knowledge_id': 'E0002', 'question': '您好！我想查一下我的veeva账号和密码'},
#  81: {'knowledge_id': 'A0006', 'question': '现在报销系统还体现不出来吗'},
#  82: {'knowledge_id': 'A0010', 'question': '我十三号提交的会议关闭'},
#  83: {'knowledge_id': 'D0004', 'question': '如何登录阿凡达网站'},
#  84: {'knowledge_id': 'A0059', 'question': '您好，我为会议购买了办公用品和展台展架，但开具的是增值税普通发票'},
#  85: {'knowledge_id': 'E0022',
#   'question': '我想问下，我产假休到这个月15号，后半个月的拜访可能会不达标吧？会影响sfe考核吗'},
#  86: {'knowledge_id': 'A0065', 'question': 'concur网址是多少'},
#  87: {'knowledge_id': 'A0065', 'question': '网页版网址concur'},
#  88: {'knowledge_id': 'A0010',
#   'question': '您好，我上周关闭的活动，到现在concur里会议活动号还没有，怎么办'},
#  89: {'knowledge_id': 'I0001', 'question': '掌上az安装不成功'},
#  90: {'knowledge_id': 'A0016', 'question': '已邮寄账单有错误，如何撤回'},
#  91: {'knowledge_id': 'A0039', 'question': '扫描中心邮箱'},
#  92: {'knowledge_id': 'A0039', 'question': '扫描中心电话'},
#  93: {'knowledge_id': 'C0001', 'question': '你好 我的k账号密码过期了 能给我重设一个密码吗？'},
#  94: {'knowledge_id': 'G0067', 'question': '无法登陆'},
#  95: {'knowledge_id': 'A0010', 'question': '上周三关闭的会议活动号报销系统中今天怎么还没出来？'},
#  96: {'knowledge_id': 'A0066', 'question': 'pin码是多少'},
#  97: {'knowledge_id': 'G0075', 'question': '易活动无法登陆'},
#  98: {'knowledge_id': 'A0039', 'question': '您好，请问有退单如何能和扫描中心联系上，电话永远都是忙打不通'},
#  99: {'knowledge_id': 'A0056', 'question': '购买笔，本等办公用品如何选择费用类型'},
#  100: {'knowledge_id': 'C0001', 'question': 'k账号今天刚改过密码 再想换一个是不是需要隔一段时间'},
#  101: {'knowledge_id': 'J0001', 'question': '请问下国旅通的登陆方式'},
#  102: {'knowledge_id': 'A0010', 'question': '我的esm13号会议就关闭了'},
#  103: {'knowledge_id': 'C0001', 'question': '你好，系统提示又要改密码'},
#  104: {'knowledge_id': 'C0001', 'question': '您好，密码过期'},
#  105: {'knowledge_id': 'C0003', 'question': 'ipad解锁密码忘记怎么办'},
#  106: {'knowledge_id': 'A0057', 'question': '内部订单号'},
#  107: {'knowledge_id': 'A0010', 'question': '前天关闭的活动，今天在concur中找不到活动号'},
#  108: {'knowledge_id': 'A0010', 'question': '你好，会议活动号在会议关闭后会在concur系统中延迟出现吗？'},
#  109: {'knowledge_id': 'C0001', 'question': '你好，我的k账号密码过期了，能帮我重新设置密码吗'},
#  110: {'knowledge_id': 'C0001', 'question': '你好我的k香港，密码过期了'},
#  111: {'knowledge_id': 'C0001', 'question': '你好我的k账号密码过期了'},
#  112: {'knowledge_id': 'C0003', 'question': '登陆不进去怎么办'},
#  113: {'knowledge_id': 'C0001',
#   'question': '新的电脑一直没用，现在要更换，但用目前的账号和密码无法登陆，又不记得之前的密码了，怎么办？'},
#  114: {'knowledge_id': 'A0081', 'question': '海外出差餐费能否一人同时报销多人？'},
#  115: {'knowledge_id': 'C0001', 'question': '你好，更改密码，过期了'},
#  116: {'knowledge_id': 'G0075', 'question': '网址'},
#  117: {'knowledge_id': 'A0065', 'question': 'concur登录不上'},
#  118: {'knowledge_id': 'C0001', 'question': '密码过期了'},
#  119: {'knowledge_id': 'G0067', 'question': '请问我系统密码过期了为什么修改不了？'},
#  120: {'knowledge_id': 'A0016', 'question': '如何撤销'},
#  121: {'knowledge_id': 'E0001', 'question': '如何下载登陆crm 系统'},
#  122: {'knowledge_id': 'E0001', 'question': '无法下载irep'},
#  123: {'knowledge_id': 'C0001', 'question': '您好！我的密码即将过期，无法自行修改，能帮我重置嚒？'},
#  124: {'knowledge_id': 'F0008', 'question': 'icustomer中客户信息如何修改'},
#  125: {'knowledge_id': 'A0050', 'question': '如何在报帐系统中，交易地点搜索陕西省'},
#  126: {'knowledge_id': 'I0037', 'question': '推送奖金政策'},
#  127: {'knowledge_id': 'A0010', 'question': '您好为何我会议活动号还未倒入concur'},
#  128: {'knowledge_id': 'J0001', 'question': '机票差旅'},
#  129: {'knowledge_id': 'D0012', 'question': '我的阿凡达，下载不了'},
#  130: {'knowledge_id': 'F0032', 'question': '客户调整如何调整？'},
#  131: {'knowledge_id': 'G0009', 'question': '关于讲课费的问题，一'},
#  132: {'knowledge_id': 'C0001', 'question': '昨天更改了密码  可是不小心忘记了'},
#  133: {'knowledge_id': 'E0001', 'question': '如何登陆veeva'},
#  134: {'knowledge_id': 'I0001', 'question': '您好，我需要掌上az的二维码'},
#  135: {'knowledge_id': 'C0001', 'question': '您好，我想问下我的密码过期了吗？'},
#  136: {'knowledge_id': 'A0065', 'question': '我的密码到期了，帮忙修改密码'},
#  137: {'knowledge_id': 'A0065', 'question': '密码到期'},
#  138: {'knowledge_id': 'C0001', 'question': '能帮我修改下k帐号密码么？'},
#  139: {'knowledge_id': 'E0029', 'question': '现在登录就提示身份验证失败'},
#  140: {'knowledge_id': 'E0002', 'question': 'veeva无法同步，提示升级后进去又升级，升了四次还是无法同步'},
#  141: {'knowledge_id': 'G0063',
#   'question': '我的讲者显示12月20号过期，我能在当天使用该讲者讲课，并且能有正常的劳务费用支付么'},
#  142: {'knowledge_id': 'C0001', 'question': '我要重置密码'},
#  143: {'knowledge_id': 'I0001', 'question': '您好，请问有掌上az的安卓下载码'},
#  144: {'knowledge_id': 'C0003', 'question': '请问域名选哪一个'},
#  145: {'knowledge_id': 'C0001', 'question': 'k账号密码重置'},
#  146: {'knowledge_id': 'A0019', 'question': '扫描中心'},
#  147: {'knowledge_id': 'E0024', 'question': 'icustomer'},
#  148: {'knowledge_id': 'C0001', 'question': 'az email的密码'},
#  149: {'knowledge_id': 'E0029', 'question': '身份验证失败'},
#  150: {'knowledge_id': 'C0001', 'question': '密码过期了吧'},
#  151: {'knowledge_id': 'E0024', 'question': '请问veeva中我的客户里没有关联客户怎么办'},
#  152: {'knowledge_id': 'G0067', 'question': '您好，kbsg860无法登陆esm系统'},
#  153: {'knowledge_id': 'A0036', 'question': '一笔刷卡包括住宿与餐费，如何报销'},
#  154: {'knowledge_id': 'F0021',
#   'question': '你好，我想问一下目标客户怎么关联，我收到短信说我的目标客户少于50人'},
#  155: {'knowledge_id': 'E0014', 'question': '您好，想问一下目标客户需要80个非n类客户？'},
#  156: {'knowledge_id': 'G0075', 'question': 'esm的网址'},
#  157: {'knowledge_id': 'C0001', 'question': '我的密码过期了'},
#  158: {'knowledge_id': 'A0065', 'question': '你好，我的concur账号密码是什么？'},
#  159: {'knowledge_id': 'E0002', 'question': '一直让输入密码'},
#  160: {'knowledge_id': 'A0036', 'question': '住宿和餐费一笔刷卡'},
#  161: {'knowledge_id': 'A0036', 'question': '酒店住宿和餐费一笔刷了，如何报销'},
#  162: {'knowledge_id': 'E0013', 'question': '年会期间，拜访怎么填写'},
#  163: {'knowledge_id': 'E0013', 'question': '年会期间拜访怎么填'},
#  164: {'knowledge_id': 'A0016', 'question': '报销单寄到审计中心，需要撤回，怎么处理'},
#  165: {'knowledge_id': 'I0037',
#   'question': '请问一下我年会推送的奖金政策跟我的tag的不一样，这个事情可以找谁呀'},
#  166: {'knowledge_id': 'A0066', 'question': '公司sso代码'},
#  167: {'knowledge_id': 'A0010', 'question': '查不到活动编号'},
#  168: {'knowledge_id': 'C0001', 'question': '平板电脑密码忘记了。怎么办'},
#  169: {'knowledge_id': 'C0001', 'question': '您好！平板密码忘记了'},
#  170: {'knowledge_id': 'H0001', 'question': '你好请问年会会务组电话'},
#  171: {'knowledge_id': 'H0001', 'question': '你好，请问年会三等奖在哪里领'},
#  172: {'knowledge_id': 'C0003', 'question': '我想问一下我现在新的老的密码都不对了怎么办输入哪个都登录不了'},
#  173: {'knowledge_id': 'C0001', 'question': '现在老密码新密码都不对'},
#  174: {'knowledge_id': 'C0003', 'question': '昨天改密码，怎么也没成功'},
#  175: {'knowledge_id': 'G0067', 'question': '我的k账号不能用了'},
#  176: {'knowledge_id': 'I0001', 'question': '我要下载掌上az，请推送二维码'},
#  177: {'knowledge_id': 'I0001', 'question': '我新购买的手机希望下载""掌上az""'},
#  178: {'knowledge_id': 'E0002',
#   'question': 'veeva系统一直显示同步失败，退出重新登录好几次都同步不了，请问怎么办？'},
#  179: {'knowledge_id': 'I0001', 'question': '问下如何下载掌上az'},
#  180: {'knowledge_id': 'I0001', 'question': '掌上az的下载'},
#  181: {'knowledge_id': 'C0001', 'question': 'k账号密码改了'},
#  182: {'knowledge_id': 'I0001', 'question': '掌上az如何下载'},
#  183: {'knowledge_id': 'I0001', 'question': '掌上az下载链接发我下'},
#  184: {'knowledge_id': 'G0078',
#   'question': '代表有个esm科会是发邮件到飞检邮箱取消的，不是在esm里面取消的。活动结束后我申请关闭活动，该如何操作？'},
#  185: {'knowledge_id': 'I0001', 'question': '你好，可以给我一个掌上az的下载地址吗？'},
#  186: {'knowledge_id': 'I0007', 'question': '微视角绩效表现客户拜访率刷新不出来'},
#  187: {'knowledge_id': 'E0029', 'question': 'veeva crm 同步数据失败'},
#  188: {'knowledge_id': 'C0003', 'question': '刚刚改的密码是az77821k吗？登录不了'},
#  189: {'knowledge_id': 'G0078', 'question': '飞检报告在公司微信公众号的哪里查询呢'},
#  190: {'knowledge_id': 'C0001', 'question': '改密码'},
#  191: {'knowledge_id': 'A0021', 'question': '跨区域市场报销燃油费是需要像dsm, rsm请示审批吗？'},
#  192: {'knowledge_id': 'A0021', 'question': '请问下，如何报销汽油费'},
#  193: {'knowledge_id': 'H0001', 'question': '请问年会下午的展台在哪里？'},
#  194: {'knowledge_id': 'E0022', 'question': '嫌疑拜访多少才影响奖金'},
#  195: {'knowledge_id': 'I0001', 'question': '如何下载掌上az'},
#  196: {'knowledge_id': 'I0001', 'question': '掌上az的下载二维码'},
#  197: {'knowledge_id': 'I0001', 'question': '请问掌上az从哪里下载?'},
#  198: {'knowledge_id': 'G0067', 'question': '请问我的esm系统怎么打不'},
#  199: {'knowledge_id': 'G0067', 'question': '请问我的esm系统怎么打不开'},
#  200: {'knowledge_id': 'C0001', 'question': '重置密码'},
#  201: {'knowledge_id': 'J0001', 'question': '你好，麻烦您能给我发一下国旅运通的登陆网址嘛'},
#  202: {'knowledge_id': 'A0110',
#   'question': '收到短信提醒icustomer客户数太少，想发邮件给7575报备。想问问7575的邮箱'},
#  203: {'knowledge_id': 'G0075', 'question': 'esm网站打不开什么原因'},
#  204: {'knowledge_id': 'J0001', 'question': '你好，有国旅运通的网址吗'},
#  205: {'knowledge_id': 'C0003', 'question': '您好，被提示密码需要更改，然后就无法正确登陆了'},
#  206: {'knowledge_id': 'E0029', 'question': '我在登陆crm的时候显示身份验证失败，无法正常登录'},
#  207: {'knowledge_id': 'E0029', 'question': '你好，我的crm系统登录显示身份验证失败是怎么回事？'},
#  208: {'knowledge_id': 'C0001', 'question': '我的密码是不是过期了'},
#  209: {'knowledge_id': 'C0003', 'question': '你好，帮我密码改一下'},
#  210: {'knowledge_id': 'C0001', 'question': '怎么更改呀'},
#  211: {'knowledge_id': 'F0023', 'question': '为什么手机搜索不到会场wifi信号'},
#  212: {'knowledge_id': 'H0001', 'question': '年会wifi'},
#  213: {'knowledge_id': 'G0005', 'question': '您好 esm里面讲者审批的邮箱能发一下吗？谢谢'},
#  214: {'knowledge_id': 'G0075', 'question': 'esm外网登陆网址？'},
#  215: {'knowledge_id': 'E0024',
#   'question': '您好，我准备添加客户，但是icustonmer系统中显示不能添加产品，这应该怎么解决？'},
#  216: {'knowledge_id': 'C0001', 'question': '密码过期，请修改'},
#  217: {'knowledge_id': 'C0001', 'question': '我想更新密码'},
#  218: {'knowledge_id': 'E0029', 'question': '验证'},
#  219: {'knowledge_id': 'F0002', 'question': '公司内网网址多少？'},
#  220: {'knowledge_id': 'C0001', 'question': '您好，我的密码过期了想改一下密码'},
#  221: {'knowledge_id': 'A0039', 'question': '如何联系财务'},
#  222: {'knowledge_id': 'C0003', 'question': '邮件也一直需要密码'},
#  223: {'knowledge_id': 'C0003', 'question': '你好，我想修改密码'},
#  224: {'knowledge_id': 'C0001', 'question': '您好！密码过期了，'},
#  225: {'knowledge_id': 'C0003', 'question': '说我密码不对'},
#  226: {'knowledge_id': 'I0037', 'question': '奖金'},
#  227: {'knowledge_id': 'D0001', 'question': '掌上az无法安装，没有证书'},
#  228: {'knowledge_id': 'A0110', 'question': '您好！公司7575热线是多少，谢谢啦'},
#  229: {'knowledge_id': 'A0066', 'question': 'sos公司代码是多少？'},
#  230: {'knowledge_id': 'A0110', 'question': 'it在吗'},
#  231: {'knowledge_id': 'I0001', 'question': '掌上az二维码'},
#  232: {'knowledge_id': 'D0004', 'question': '阿凡达 网页版'},
#  233: {'knowledge_id': 'D0012', 'question': '阿凡达有手机app吗'},
#  234: {'knowledge_id': 'C0001', 'question': '您好，需要修改密码'},
#  235: {'knowledge_id': 'I0001', 'question': '帮忙发送一个下载掌上az的二维码'},
#  236: {'knowledge_id': 'A0066', 'question': '公司代码是什么'},
#  237: {'knowledge_id': 'C0003', 'question': '帮我改下密码'},
#  238: {'knowledge_id': 'C0003', 'question': '我的密码改了好几次都改不成功，请帮我改一下吧'},
#  239: {'knowledge_id': 'G0075', 'question': '您好 帮忙发一下esm网页版网址 谢谢'},
#  240: {'knowledge_id': 'G0067', 'question': '等不了账号'},
#  241: {'knowledge_id': 'D0012', 'question': '掌上az，无法下载无法使用'},
#  242: {'knowledge_id': 'C0003', 'question': '你好，掌上az无法登陆'},
#  243: {'knowledge_id': 'C0003', 'question': 'windows10 怎么选网络？'},
#  244: {'knowledge_id': 'C0001', 'question': '公司首页上不去，一直让输入密码'},
#  245: {'knowledge_id': 'D0004', 'question': '求网页版阿凡达'},
#  246: {'knowledge_id': 'C0003', 'question': '请问网页版的预估账号和密码是'},
#  247: {'knowledge_id': 'A0042', 'question': '新员工报销'},
#  248: {'knowledge_id': 'A0094', 'question': '请问发票丢失怎么办'},
#  249: {'knowledge_id': 'E0029', 'question': '我的veeva显示身份验证失败怎么弄'},
#  250: {'knowledge_id': 'I0006', 'question': '你好it安全培训一直无法打开'},
#  251: {'knowledge_id': 'I0001', 'question': '掌上az的下载链接能给我一下么？'},
#  252: {'knowledge_id': 'G0075', 'question': 'esm网址是什么'},
#  253: {'knowledge_id': 'A0020', 'question': '这个是银行卡利息产生的concur，这边怎么报销啊？'},
#  254: {'knowledge_id': 'A0023', 'question': '那我本月的账单已经报销过了，那您看怎么再继续报销？'},
#  255: {'knowledge_id': 'I0001', 'question': '掌上az下载地址'},
#  256: {'knowledge_id': 'A0020', 'question': '银行循环利息'},
#  257: {'knowledge_id': 'C0001', 'question': '需要重新更改密码'},
#  258: {'knowledge_id': 'A0025', 'question': '请问有刷卡记录不报销，该如何处理？收到系统邮件了。'},
#  259: {'knowledge_id': 'C0001', 'question': '如果修改公司密码？'},
#  260: {'knowledge_id': 'C0001', 'question': '如何修改公司密码？？'},
#  261: {'knowledge_id': 'C0003', 'question': '你好！kttw907。的账号密码忘记了'},
#  262: {'knowledge_id': 'C0001', 'question': '麻烦帮我重置一下密码'},
#  263: {'knowledge_id': 'I0001', 'question': '请问新手机如何下载掌上az？谢谢！'},
#  264: {'knowledge_id': 'C0002', 'question': '请问预估网页版网址是什么'},
#  265: {'knowledge_id': 'C0003', 'question': '如何登陆网页版预估'},
#  266: {'knowledge_id': 'C0003', 'question': '电脑升级电脑升级后如何登录'},
#  267: {'knowledge_id': 'C0003', 'question': '需要改密码'},
#  268: {'knowledge_id': 'C0001', 'question': '密码过期，需要修改密码'},
#  269: {'knowledge_id': 'E0029',
#   'question': 'veeva crm app 同步时出现报错""身份验证失败，切换网络或稍后再试""'},
#  270: {'knowledge_id': 'D0012', 'question': '您好，请问如何下载掌上az'},
#  271: {'knowledge_id': 'D0012', 'question': '请问如何下载掌上a?z'},
#  272: {'knowledge_id': 'I0001', 'question': '您好请问如何下载掌上a?z'},
#  273: {'knowledge_id': 'C0001', 'question': '密码过期需要重置'},
#  274: {'knowledge_id': 'C0001', 'question': '您好，能不能帮我重置下密码'},
#  275: {'knowledge_id': 'C0001', 'question': '秘密过期了'},
#  276: {'knowledge_id': 'C0001', 'question': '密码重置'},
#  277: {'knowledge_id': 'A0110', 'question': '7575座席忙，可以让他们一会给我打电话吗？'},
#  278: {'knowledge_id': 'C0003', 'question': '我需要更改密码，请在方便时与我联系'},
#  279: {'knowledge_id': 'I0001', 'question': '下载掌上az'},
#  280: {'knowledge_id': 'C0003', 'question': '如何修改登录密码'},
#  281: {'knowledge_id': 'C0001', 'question': '密码失效重置'},
#  282: {'knowledge_id': 'C0001', 'question': '密码过期怎么改？'},
#  283: {'knowledge_id': 'G0071', 'question': '讲者简历电子版'},
#  284: {'knowledge_id': 'A0110', 'question': '请问it应该找谁'},
#  285: {'knowledge_id': 'C0003', 'question': '你好，麻烦帮我解锁'},
#  286: {'knowledge_id': 'C0001', 'question': '你好，麻烦帮我k帐号解锁'},
#  287: {'knowledge_id': 'A0066', 'question': '请问进入concur的公司代码是什么？谢谢！'},
#  288: {'knowledge_id': 'A0066', 'question': '下载了但是总是提示无法登陆'},
#  289: {'knowledge_id': 'A0065', 'question': '输入的密码也是正确的'},
#  290: {'knowledge_id': 'C0003',
#   'question': '所以concor系统得重新下载，下载好了之后输入k账号和密码就无法登陆'},
#  291: {'knowledge_id': 'A0065', 'question': '提示输入密码或者pin'},
#  292: {'knowledge_id': 'A0065', 'question': '可是开机密码不对'},
#  293: {'knowledge_id': 'C0001', 'question': '修改密码'},
#  294: {'knowledge_id': 'G0076', 'question': '这个esm无法安装'},
#  295: {'knowledge_id': 'A0066', 'question': '手机下载concur,如何登陆'},
#  296: {'knowledge_id': 'A0066', 'question': 'sso公司代码为多少'},
#  297: {'knowledge_id': 'C0001', 'question': '我的密码好像过期了'},
#  298: {'knowledge_id': 'C0001', 'question': '我的k账号密码到期了'},
#  299: {'knowledge_id': 'E0029', 'question': '您好，irep添加客户后无法同步，出现身份验证失败'},
#  300: {'knowledge_id': 'I0001', 'question': '我想知道掌上az怎么下载？'},
#  301: {'knowledge_id': 'G0071', 'question': '您好，我想查看讲者的打款进度？应该从哪看'},
#  302: {'knowledge_id': 'G0077', 'question': '您好。esm活动怎么没有提交的那个选项啦。'},
#  303: {'knowledge_id': 'A0006',
#   'question': '11月日常报销已提交，已产生er号为何在系统中看不到了？谢谢？如何找到？'},
#  304: {'knowledge_id': 'A0072', 'question': '报告库中没有'},
#  305: {'knowledge_id': 'H0001', 'question': '年会'},
#  306: {'knowledge_id': 'E0032', 'question': 'veeva总是显示没有互联网连接'},
#  307: {'knowledge_id': 'D0012', 'question': '我的阿凡达下载不了'},
#  308: {'knowledge_id': 'D0012', 'question': '以前有阿凡达的，突然间不见了'},
#  309: {'knowledge_id': 'C0001', 'question': 'k帐号解锁'},
#  310: {'knowledge_id': 'I0001', 'question': '你好 我想下载掌上az 如何下载'},
#  311: {'knowledge_id': 'C0001', 'question': '我密码过期了'},
#  312: {'knowledge_id': 'G0022', 'question': '议程主题缺少'},
#  313: {'knowledge_id': 'J0001', 'question': '有国旅运通的网址吗'},
#  314: {'knowledge_id': 'C0001', 'question': '密码已经过期'},
#  315: {'knowledge_id': 'C0001', 'question': '麻烦帮我重置一下'},
#  316: {'knowledge_id': 'C0001', 'question': '密码能不能给我重置一下'},
#  317: {'knowledge_id': 'C0001', 'question': 'kljl605，13450492135，更改密码'},
#  318: {'knowledge_id': 'C0001', 'question': '我的密码已经过期，自己改不了密码，着急上系统提交预估'},
#  319: {'knowledge_id': 'C0003', 'question': '给我改一下密码'},
#  320: {'knowledge_id': 'A0110', 'question': '你好为什么没有it设备资讯的选项'},
#  321: {'knowledge_id': 'I0001', 'question': '你好，掌上az下载后打不开'},
#  322: {'knowledge_id': 'C0003', 'question': '您好 我忘记密码了'},
#  323: {'knowledge_id': 'C0001', 'question': '请问前面忘记密码 在station里回答安全问题 错误次数太多'},
#  324: {'knowledge_id': 'E0001', 'question': '邮箱，veeva实码都不对，请问是不是过期了'},
#  325: {'knowledge_id': 'A0019', 'question': '我想问问我纸质发票扫描中心没收到的问题'},
#  326: {'knowledge_id': 'G0071', 'question': '我这边11月3号的一个会议讲者费用还没付，麻烦能催一下吗'},
#  327: {'knowledge_id': 'C0003', 'question': '麻烦更改一下密码 我的k账号kblw265'},
#  328: {'knowledge_id': 'G0075', 'question': '请问外网网址是'},
#  329: {'knowledge_id': 'C0001', 'question': '修改密码。'},
#  330: {'knowledge_id': 'A0094', 'question': '你好，我的发票在做完费用报销网上录入后丢失'},
#  331: {'knowledge_id': 'C0001', 'question': '你好，密码过期了，需要更改密码'},
#  332: {'knowledge_id': 'C0001', 'question': '您好，麻烦帮我改一下密码'},
#  333: {'knowledge_id': 'C0003', 'question': '我明天过去修ipad'},
#  334: {'knowledge_id': 'H0001', 'question': '年会你们在澳门吗？'},
#  335: {'knowledge_id': 'A0110', 'question': 'it服务台'},
#  336: {'knowledge_id': 'A0006',
#   'question': 'concur系统中10月报销相关材料已补齐并于12月11日将10月和11月的报销都已重新提交报告，什么时候报销会下来，'},
#  337: {'knowledge_id': 'I0001', 'question': '你好，怎么下载掌上az'},
#  338: {'knowledge_id': 'H0001', 'question': '年会在澳门吃饭怎么报销'},
#  339: {'knowledge_id': 'C0001', 'question': '能幫我重置下k賬號密碼吗？'},
#  340: {'knowledge_id': 'C0001', 'question': '需要密码重置'},
#  341: {'knowledge_id': 'C0003', 'question': '请帮我更改一下k账号密码'},
#  342: {'knowledge_id': 'C0003', 'question': '你好麻烦帮忙改一下密码，谢谢'},
#  343: {'knowledge_id': 'C0003', 'question': '修改k账号密码'},
#  344: {'knowledge_id': 'I0001', 'question': '掌上az下载了 但是报错不能进入'},
#  345: {'knowledge_id': 'C0001', 'question': '密码到期后如何获取新密码'},
#  346: {'knowledge_id': 'H0001', 'question': '年会无法签到'},
#  347: {'knowledge_id': 'C0003',
#   'question': '你好，pad更新系统之后，激活锁无法登陆，pad原始账户和密码不知道怎么办'},
#  348: {'knowledge_id': 'A0043', 'question': '已寄出报销单但是显示未收到'},
#  349: {'knowledge_id': 'A0075', 'question': '已寄出纸质账单但显示未收到'},
#  350: {'knowledge_id': 'C0001', 'question': '你好！密码过期'},
#  351: {'knowledge_id': 'C0001', 'question': '我的k密码需要重置，自己操作不了'},
#  352: {'knowledge_id': 'C0001', 'question': '已经过期'},
#  353: {'knowledge_id': 'C0001', 'question': '您好，麻烦您帮我密码重置'},
#  354: {'knowledge_id': 'C0003', 'question': 'pad系统更新之后无法登陆激活账号'},
#  355: {'knowledge_id': 'C0001', 'question': '我的k账号锁了，请帮我解锁'},
#  356: {'knowledge_id': 'C0003', 'question': '改密码改不了'},
#  357: {'knowledge_id': 'C0003', 'question': '老密码登录不上'},
#  358: {'knowledge_id': 'C0003', 'question': '您能帮忙改下密码吗？'},
#  359: {'knowledge_id': 'I0008', 'question': '掌上az安装'},
#  360: {'knowledge_id': 'C0001', 'question': '你好，我密码过期，需要重置，谢谢'},
#  361: {'knowledge_id': 'C0001',
#   'question': '昨天我ipad密码过期  我重新修改了下  密码设置的都是汉语拼音 当时没注意好像有一个字母设置了大写  但是现在我就不清了  现在ipad被锁住了 打不开了'},
#  362: {'knowledge_id': 'E0002', 'question': '我的veeva一直登不进显示账号错误'},
#  363: {'knowledge_id': 'I0037', 'question': '你好！问下2018年的销售奖金政策有发出来嘛？'},
#  364: {'knowledge_id': 'C0001', 'question': '密码到期，如何获取新密码'},
#  365: {'knowledge_id': 'I0001', 'question': '掌上az怎么安装，apple系统'},
#  366: {'knowledge_id': 'A0105', 'question': '私车公用申请'},
#  367: {'knowledge_id': 'I0001', 'question': '您好！能否再帮推送掌上az，手机更新后没有了。谢谢！'},
#  368: {'knowledge_id': 'I0001', 'question': '请问掌上az在哪里下载'},
#  369: {'knowledge_id': 'D0012', 'question': '手机版的掌上az在哪里下载'},
#  370: {'knowledge_id': 'I0001', 'question': '我要下载掌上az'},
#  371: {'knowledge_id': 'E0020', 'question': '安装irep'},
#  372: {'knowledge_id': 'I0001', 'question': '你好，我掌上az，打开有问题'},
#  373: {'knowledge_id': 'C0003', 'question': '密码忘了  你们帮我解锁了好几次  还是没用'},
#  374: {'knowledge_id': 'E0029', 'question': '拜访系统k账号无法登入，显示身份验证失败，，'},
#  375: {'knowledge_id': 'C0003', 'question': '你好，请问这个情况是什么意思？不知道密码'},
#  376: {'knowledge_id': 'A0103', 'question': '信用卡进度'},
#  377: {'knowledge_id': 'A0110', 'question': '请问怎么可以联系到it呢'},
#  378: {'knowledge_id': 'A0105', 'question': '申请私车公用怎么申请？'},
#  379: {'knowledge_id': 'C0003', 'question': '我是新员工，我的拜访的账号密码是什么'},
#  380: {'knowledge_id': 'A0105', 'question': '私车公用'},
#  381: {'knowledge_id': 'D0020', 'question': '我的全球网络安全意识完成了'},
#  382: {'knowledge_id': 'E0029', 'question': 'crm不能同步，卸载重新下载后显示身份验证失败'},
#  383: {'knowledge_id': 'I0037',
#   'question': '你好，年会推送给我的是奖金政策 cvx-c，可我是属于cvc的，奖金政策能重新推送给我吗？'},
#  384: {'knowledge_id': 'C0001', 'question': '你好我的密码过期了，可以自己改吗？怎么改？'},
#  385: {'knowledge_id': 'I0001', 'question': '能发我一下掌上az的二维码么，从ios换成安卓了'},
#  386: {'knowledge_id': 'C0001', 'question': '我希望重新设置k账号的密码'},
#  387: {'knowledge_id': 'A0052',
#   'question': '您好，我用大众点评订了外卖，然后退款了，后来concur上出现了2笔相关费用，一次是这笔消费769.5元，一笔是退款负769.5元，应该怎么解决'},
#  388: {'knowledge_id': 'C0001', 'question': '账号无法登入'},
#  389: {'knowledge_id': 'A0027', 'question': '还是无法下载'},
#  390: {'knowledge_id': 'A0041', 'question': '系统最快出帐是多长时间'},
#  391: {'knowledge_id': 'E0029', 'question': 'veeva同步失败'},
#  392: {'knowledge_id': 'E0017', 'question': '拜访考核'},
#  393: {'knowledge_id': 'E0004', 'question': '拜访次数要求'},
#  394: {'knowledge_id': 'J0001', 'question': '差旅预定机票是在那个网址呢？'},
#  395: {'knowledge_id': 'I0037', 'question': '我的奖金个人定制版是否推送错了'},
#  396: {'knowledge_id': 'I0037', 'question': '18年个人奖金政策'},
#  397: {'knowledge_id': 'A0019', 'question': '扫描中心邮寄地址'},
#  398: {'knowledge_id': 'E0013', 'question': '你好，我可以删除周末填拜访吗？'},
#  399: {'knowledge_id': 'E0021', 'question': '因为这个月年会时间紧张，周六周日都在拜访客户'},
#  400: {'knowledge_id': 'A0110', 'question': 'it归还'},
#  401: {'knowledge_id': 'I0002', 'question': '未受信任'},
#  402: {'knowledge_id': 'D0004', 'question': '阿凡达的网页'},
#  403: {'knowledge_id': 'A0110', 'question': 'it服务台我应该找谁'},
#  404: {'knowledge_id': 'D0012', 'question': '阿凡达无法现在下载'},
#  405: {'knowledge_id': 'E0005', 'question': '你好，请问veeva的网页版网址'},
#  406: {'knowledge_id': 'C0003', 'question': '请问worjday用什么登陆 一直显示用户名或密码错误'},
#  407: {'knowledge_id': 'C0003', 'question': '请问新的k账号密码在哪查询'},
#  408: {'knowledge_id': 'G0067', 'question': '密码显示错误'},
#  409: {'knowledge_id': 'H0001', 'question': '年会日程'},
#  410: {'knowledge_id': 'E0001', 'question': '我的irep无法下载'},
#  411: {'knowledge_id': 'C0003', 'question': '你好，我再改密码的时候 提示旧密码已失效。'},
#  412: {'knowledge_id': 'A0039', 'question': '我想问下审计的10天包含周末么'},
#  413: {'knowledge_id': 'D0012', 'question': '亲 我下载不了软件阿凡达'},
#  414: {'knowledge_id': 'H0007', 'question': '机票改签'},
#  415: {'knowledge_id': 'C0003', 'question': '系统升级密码是什么'},
#  416: {'knowledge_id': 'G0062', 'question': '城市会算考核的会议吗'},
#  417: {'knowledge_id': 'C0001', 'question': '你好，我想重置k账号密码'},
#  418: {'knowledge_id': 'I0037', 'question': '你好，我新岗位的奖金政策没推送，这边可以反馈吗？谢谢'},
#  419: {'knowledge_id': 'I0001', 'question': '手机版掌上az更新版本后无法使用'},
#  420: {'knowledge_id': 'C0001', 'question': '电脑密码过期'},
#  421: {'knowledge_id': 'C0001', 'question': '修改密码，出现现在无法鉴定该用户名'},
#  422: {'knowledge_id': 'G0067', 'question': 'esm登不进去'},
#  423: {'knowledge_id': 'C0001', 'question': '您好，我的密码过期 麻烦帮忙重新设置一下'},
#  424: {'knowledge_id': 'A0065', 'question': 'concur账号密码？怎么填写'},
#  425: {'knowledge_id': 'G0071', 'question': '请问讲者审批的第三方有联系方式吗'},
#  426: {'knowledge_id': 'A0066', 'question': 'sso公司代码'},
#  427: {'knowledge_id': 'C0003', 'question': '登入提示密码错误。但是这个密码确认没有改过，并且其它软件能进去'},
#  428: {'knowledge_id': 'D0012', 'question': '请问如何下载ppt'},
#  429: {'knowledge_id': 'I0008', 'question': '掌上az安装不了'},
#  430: {'knowledge_id': 'A0022', 'question': '11月份的油票还是不能报销，如果我删除的话是算审计扣款吗？'},
#  431: {'knowledge_id': 'A0065', 'question': '系统升级，不知道用户名跟密码'},
#  432: {'knowledge_id': 'C0003', 'question': '用户名跟密码是什么呀'},
#  433: {'knowledge_id': 'E0001', 'question': 'pad上没法下载veeva了怎们弄'},
#  434: {'knowledge_id': 'C0001', 'question': '你好，能帮改一下k帐号密码吗'},
#  435: {'knowledge_id': 'G0057', 'question': '就是我在结束活动的时候，会议实际结束的时间用改吗？'},
#  436: {'knowledge_id': 'E0029', 'question': '身份验证失败，请切换网络或者稍后再尝试'},
#  437: {'knowledge_id': 'G0009', 'question': '讲课费'},
#  438: {'knowledge_id': 'E0001', 'question': 'veeva 系统如何下载'},
#  439: {'knowledge_id': 'I0001', 'question': '您好，掌上az 无法下载'},
#  440: {'knowledge_id': 'I0001', 'question': '掌上az 无法下载'},
#  441: {'knowledge_id': 'A0074', 'question': '账单封面'},
#  442: {'knowledge_id': 'E0001', 'question': '目前下载不了veeva crm 怎么办'},
#  443: {'knowledge_id': 'E0005', 'question': 'veeva登录不上去'},
#  444: {'knowledge_id': 'E0005', 'question': 'veeva登录与权限'},
#  445: {'knowledge_id': 'E0005', 'question': 'veeva登录无权限'},
#  446: {'knowledge_id': 'E0005', 'question': 'veeva登录'},
#  447: {'knowledge_id': 'C0001', 'question': '怎么解锁'},
#  448: {'knowledge_id': 'A0039', 'question': '请问审计中心的联系方式你有么'},
#  449: {'knowledge_id': 'A0094', 'question': '发票丢失'},
#  450: {'knowledge_id': 'I0001', 'question': '你好，我的掌上az进不去'},
#  451: {'knowledge_id': 'G0073', 'question': '易活动直线经理审批过去，但是发现信息不对'},
#  452: {'knowledge_id': 'G0001', 'question': '您看我这为什么内部订单号搜索不出来'},
#  453: {'knowledge_id': 'I0007', 'question': '想咨询一下掌上az上不显示biso微视角'},
#  454: {'knowledge_id': 'A0019', 'question': '扫描中心地址？'},
#  455: {'knowledge_id': 'I0001', 'question': '掌上azpad上能装吗？'},
#  456: {'knowledge_id': 'E0029', 'question': '身份验证失败，该如何解决'},
#  457: {'knowledge_id': 'G0029', 'question': '你好，我想问一下科室会外部参会人数至少是几个'},
#  458: {'knowledge_id': 'I0001', 'question': '请提供我掌上az的二维码'},
#  459: {'knowledge_id': 'A0075', 'question': '餐费一个月不超过多少'},
#  460: {'knowledge_id': 'E0050', 'question': '请问我的微信veeva无法确认辅导报告怎么回事'},
#  461: {'knowledge_id': 'C0001', 'question': '你好我的拜访系统密码显示错误'},
#  462: {'knowledge_id': 'C0001', 'question': 'k 账号密码到期'},
#  463: {'knowledge_id': 'A0107', 'question': '培训时候餐费如何报销'},
#  464: {'knowledge_id': 'C0001', 'question': '重置密码的领域选哪个，为什么az进不去'},
#  465: {'knowledge_id': 'E0029', 'question': '显示身份验证失败'},
#  466: {'knowledge_id': 'I0001', 'question': '想咨询关于掌上az问题可以吗？'},
#  467: {'knowledge_id': 'E0047', 'question': '您好，veeva系统用手机可以同步吗？'},
#  468: {'knowledge_id': 'A0065', 'question': 'concur网页版怎么登陆'},
#  469: {'knowledge_id': 'A0022', 'question': '一套完整的concur报销是什么流程'},
#  470: {'knowledge_id': 'I0001', 'question': '下载掌上az后无法登陆'},
#  471: {'knowledge_id': 'D0004', 'question': '你好我的阿凡达app更新内容很慢我用，网页版的学习'},
#  472: {'knowledge_id': 'A0110', 'question': 'it问题'},
#  473: {'knowledge_id': 'G0075', 'question': '活动提交关闭后，还可以改用餐地址吗'},
#  474: {'knowledge_id': 'A0110', 'question': '公司7575联系电话多少呀？'},
#  475: {'knowledge_id': 'I0001', 'question': '掌上az app'},
#  476: {'knowledge_id': 'C0003', 'question': '我的k账号密码不能登录了，新密码告诉我一下'},
#  477: {'knowledge_id': 'C0001', 'question': '麻烦帮我看下crm密码是不是过期了'},
#  478: {'knowledge_id': 'A0066', 'question': '请问公司sso代码是多少呢'},
#  479: {'knowledge_id': 'E0029', 'question': '登陆时提示身份验证失败'},
#  480: {'knowledge_id': 'E0029', 'question': '登陆veeva提示身份验证失败'},
#  481: {'knowledge_id': 'E0001', 'question': '更新了ipad,veeva依旧安装不了'},
#  482: {'knowledge_id': 'E0029', 'question': '登陆显示身份验证失败'},
#  483: {'knowledge_id': 'G0029', 'question': '科室会参会人数少怎么办'},
#  484: {'knowledge_id': 'C0001', 'question': '下次请密码过期前，系统提示一下，好吗'},
#  485: {'knowledge_id': 'C0001', 'question': '你好，密码被锁'},
#  486: {'knowledge_id': 'E0029', 'question': '说我的身份需要验证'},
#  487: {'knowledge_id': 'E0004', 'question': '没同步好的veeva数据哪里找回'},
#  488: {'knowledge_id': 'E0029', 'question': '同步不了，提示身份验证失败，换个网络重新尝试是怎么回事'},
#  489: {'knowledge_id': 'G0001', 'question': '新的订单号找不出来'},
#  490: {'knowledge_id': 'G0001', 'question': '如何查找内部订单号'},
#  491: {'knowledge_id': 'G0049', 'question': '您好，请教一下，科室会12的当月忘记关闭了，今天关闭可以吗？'},
#  492: {'knowledge_id': 'A0065', 'question': '你好，concur 登入用户名是什么'},
#  493: {'knowledge_id': 'A0102', 'question': '请问下，公司的信用卡可以还最低还款额吗'},
#  494: {'knowledge_id': 'A0065', 'question': '要个concur网址'},
#  495: {'knowledge_id': 'C0001', 'question': 'k帐号密码过期，i t重置后微视角提示不是授权人员怎么操作'},
#  496: {'knowledge_id': 'C0003', 'question': '您好，修改密码在哪修改呢'},
#  497: {'knowledge_id': 'I0001', 'question': '你好，苹果手机怎么下载掌上az'},
#  498: {'knowledge_id': 'I0001', 'question': '你好，苹果手机掌上az怎么弄'},
#  499: {'knowledge_id': 'I0007', 'question': '我的biso微视角没办法使用了'},
#  500: {'knowledge_id': 'A0020', 'question': '如何填写报销'},
#  501: {'knowledge_id': 'C0003', 'question': '密码'},
#  502: {'knowledge_id': 'A0110', 'question': '请问it服务台地址'},
#  503: {'knowledge_id': 'E0029', 'question': '为什么我offveeva 同步 一直显示连接 一直转圈'},
#  504: {'knowledge_id': 'D0004', 'question': '阿凡达网址是什么'},
#  505: {'knowledge_id': 'E0026', 'question': '非拜访活动能否补填'},
#  506: {'knowledge_id': 'G0067', 'question': '无法登录esm系统'},
#  507: {'knowledge_id': 'E0004', 'question': '同步不了数据'},
#  508: {'knowledge_id': 'E0029', 'question': '更新数据显示身份验证失败'},
#  509: {'knowledge_id': 'C0001', 'question': '我的密码已经过期还能自己改吗'},
#  510: {'knowledge_id': 'E0022', 'question': '我有问题咨询'},
#  511: {'knowledge_id': 'G0067', 'question': 'esm登陆上客户信息都没有'},
#  512: {'knowledge_id': 'G0016', 'question': 'esm里看不到订单号'},
#  513: {'knowledge_id': 'C0001', 'question': 'kmbm259的密码'},
#  514: {'knowledge_id': 'G0079', 'question': '您好。18年成本中心变了。今天申请会议。新的会议编码搜索不到'},
#  515: {'knowledge_id': 'A0039', 'question': '审计电话始终打不通'},
#  516: {'knowledge_id': 'G0054', 'question': 'esm做会议申请是无法搜索出18年新添加的目标医院'},
#  517: {'knowledge_id': 'I0011', 'question': '您好，忘记密码'},
#  518: {'knowledge_id': 'A0110', 'question': 'it电话'},
#  519: {'knowledge_id': 'E0002', 'question': '你好，能帮我看一下我的密码吗'},
#  520: {'knowledge_id': 'E0016', 'question': '现在输入不正确不知道更改的有没有变化'},
#  521: {'knowledge_id': 'A0039', 'question': '您好，想问一下扫描中心的邮箱是多少'},
#  522: {'knowledge_id': 'C0001',
#   'question': 'ipad开机密码过期，pad又无法连接上网络，现在pad被禁用了15分钟'},
#  523: {'knowledge_id': 'C0001',
#   'question': 'ipad开机密码过期，pad又无法连接上网络，现在pad被禁用了15分钟，现在的地方的网络以前是自动连接上去的，今天也不能自动连接了'},
#  524: {'knowledge_id': 'A0065', 'question': '刚下载的concur登录页面用公司代卖码登录，登不进去'},
#  525: {'knowledge_id': 'A0094', 'question': '你好，如果用餐只有水单发票遗失怎么办？'},
#  526: {'knowledge_id': 'I0008', 'question': '请问18年幻灯在哪里下载'},
#  527: {'knowledge_id': 'G0067', 'question': '我的职位发生了变动，k账号和邮箱需要变嘛？'},
#  528: {'knowledge_id': 'E0047', 'question': '如何给手机邮箱绑定公司邮箱'},
#  529: {'knowledge_id': 'F0019', 'question': '我的计算名发给你'},
#  530: {'knowledge_id': 'E0022', 'question': '如何联系biso部门'},
#  531: {'knowledge_id': 'A0010', 'question': 'concur上活动号几天导入啊？'},
#  532: {'knowledge_id': 'G0047', 'question': '讲者变更'},
#  533: {'knowledge_id': 'C0001', 'question': '你好，这个密码忘记了'},
#  534: {'knowledge_id': 'A0065', 'question': '网页版concur怎么登陆'},
#  535: {'knowledge_id': 'A0065', 'question': '用户名不知道什么？'},
#  536: {'knowledge_id': 'I0001', 'question': '寻掌上az二维码'},
#  537: {'knowledge_id': 'A0065', 'question': '你好，网页版concur登上去用户名和密码是什么？'},
#  538: {'knowledge_id': 'E0028', 'question': '请问这如何解决'},
#  539: {'knowledge_id': 'G0005', 'question': '不好意思 想问下我11月的所有讲课费怎么都发了邮件还未付款'},
#  540: {'knowledge_id': 'C0003', 'question': '我需要授权box登陆'},
#  541: {'knowledge_id': 'D0019', 'question': '你好！请问手机安装公司邮箱的程序是怎么样的？'},
#  542: {'knowledge_id': 'A0087', 'question': '之前财务关账，未关联信用卡怎么处理'},
#  543: {'knowledge_id': 'G0005', 'question': '您好，问一下苹果手机怎么配置邮件？'},
#  544: {'knowledge_id': 'G0045', 'question': '全面分产品销售数据查询从哪里可以查寻'},
#  545: {'knowledge_id': 'E0001', 'question': 'box怎么用？谢谢！'},
#  546: {'knowledge_id': 'A0094', 'question': '发票遗失'},
#  547: {'knowledge_id': 'G0042', 'question': 'e活动无法添加产品'},
#  548: {'knowledge_id': 'C0001', 'question': '你好，我的密码过期了，要重置一下怎么操作'},
#  549: {'knowledge_id': 'A0110', 'question': '您好！我想问一下公司无锡电话是多少？'},
#  550: {'knowledge_id': 'A0065', 'question': '网页版concur地址'},
#  551: {'knowledge_id': 'F0040', 'question': '待筛选邮件怎么调整到收件箱里面？'},
#  552: {'knowledge_id': 'C0001', 'question': '我换电话了，在哪个系统里更改？'},
#  553: {'knowledge_id': 'C0003', 'question': '我想登陆公司网站'},
#  554: {'knowledge_id': 'C0003', 'question': '怎么登陆自己家里网络'},
#  555: {'knowledge_id': 'I0001', 'question': '你好，请问我的掌上az登陆不进去'},
#  556: {'knowledge_id': 'D0005', 'question': '出现这个界面'},
#  557: {'knowledge_id': 'D0018', 'question': '微信微视角显示无权限'},
#  558: {'knowledge_id': 'A0055', 'question': '2017年未报的车费能今年1月份可以报吗！'},
#  559: {'knowledge_id': 'A0029', 'question': '帮我设置下concur系统代理人呢'},
#  560: {'knowledge_id': 'A0031', 'question': '如何订机票'},
#  561: {'knowledge_id': 'E0043', 'question': '请问拜访模板怎么添加到拜访日程中？'},
#  562: {'knowledge_id': 'F0040', 'question': '绑定邮箱'},
#  563: {'knowledge_id': 'F0040', 'question': '绑定公司邮箱'},
#  564: {'knowledge_id': 'C0001', 'question': '您好，我密码到期了，能帮忙修改吗？谢谢'},
#  565: {'knowledge_id': 'I0001', 'question': '我的掌上az'},
#  566: {'knowledge_id': 'D0004', 'question': '你好我的电脑无法上网'},
#  567: {'knowledge_id': 'D0001', 'question': '网络无法显示'},
#  568: {'knowledge_id': 'D0004', 'question': '我的电脑无法上网了'},
#  569: {'knowledge_id': 'D0004', 'question': '公司it已经下班了'},
#  570: {'knowledge_id': 'I0011', 'question': 'ipad密码一直提示错误'},
#  571: {'knowledge_id': 'F0018', 'question': 'icustome客户怎么转移到分院'},
#  572: {'knowledge_id': 'A0065', 'question': '你好，你的系统网页登不上？'},
#  573: {'knowledge_id': 'A0065', 'question': '登不上，打不开网页？必须用谷歌吗？'},
#  574: {'knowledge_id': 'F0040', 'question': '我需要做绩效，但workday里面收件箱没有这份邮件'},
#  575: {'knowledge_id': 'A0065', 'question': 'concur网页版网址'},
#  576: {'knowledge_id': 'F0040', 'question': '您好，公司邮箱的网址发一下吧'},
#  577: {'knowledge_id': 'G0058', 'question': '怎么升级为城市级讲者'},
#  578: {'knowledge_id': 'F0007', 'question': '请问您这个乱码是怎么回事啊'},
#  579: {'knowledge_id': 'E0028', 'question': '您好！科室会'},
#  580: {'knowledge_id': 'A0085', 'question': '您看一下我的酒店住宿分列明细对吗'},
#  581: {'knowledge_id': 'A0065', 'question': '我需要concur网页版的网址'},
#  582: {'knowledge_id': 'I0004', 'question': '你好，我换大区，原来17年的insight系统数据没了'},
#  583: {'knowledge_id': 'I0004', 'question': '你好，我换大区了，17年的历史数据insight系统看不到了'},
#  584: {'knowledge_id': 'F0015', 'question': 'win 10升级后电脑连接打印机要重新装驱动吗'},
#  585: {'knowledge_id': 'F0040', 'question': '为什么老收到这个邮件'},
#  586: {'knowledge_id': 'E0050', 'question': '不能为代表做协访'},
#  587: {'knowledge_id': 'I0007', 'question': '经理的微视角怎么进？'},
#  588: {'knowledge_id': 'A0010', 'question': '费用导入之后，易活动，选择不上对应的活动号，怎么办'},
#  589: {'knowledge_id': 'A0066', 'question': 'sso公司代码怎么查'},
#  590: {'knowledge_id': 'F0040', 'question': '公司邮箱网址'},
#  591: {'knowledge_id': 'F0040', 'question': '请问公司邮箱网址是什么'},
#  592: {'knowledge_id': 'G0071', 'question': '查询讲者'},
#  593: {'knowledge_id': 'A0094', 'question': '已寄出纸质账单'},
#  594: {'knowledge_id': 'A0019', 'question': '已邮寄纸质账单但显示未收到'},
#  595: {'knowledge_id': 'J0001', 'question': '公司差旅系统的地址'},
#  596: {'knowledge_id': 'A0065', 'question': 'concue系统网络版网址'},
#  597: {'knowledge_id': 'A0103', 'question': '我要电脑端的报销网址'},
#  598: {'knowledge_id': 'C0001', 'question': '你好，我的账号密码过期了，想要重置一下密码'},
#  599: {'knowledge_id': 'E0029', 'question': 'ipad登陆veeva提示身份验证不通过'},
#  600: {'knowledge_id': 'A0016', 'question': '请问这个在哪里撤回费用呢'},
#  601: {'knowledge_id': 'A0110', 'question': '你好，请问公司id是多少'},
#  602: {'knowledge_id': 'A0110',
#   'question': '您好，我的电脑年会期间送到it那里了，放了一天拿回来，怎么还是没有给升级啊？'},
#  603: {'knowledge_id': 'A0110', 'question': '开始键找到vpn但没办法打开，也没办法链接上'},
#  604: {'knowledge_id': 'A0098', 'question': '住宿发票开了普通发票'},
#  605: {'knowledge_id': 'C0003', 'question': '我的apple id 密码忘记了'},
#  606: {'knowledge_id': 'I0001', 'question': '你好，掌上az苹果手机怎么下载'},
#  607: {'knowledge_id': 'A0077', 'question': '医疗专业人士用品如何报销'},
#  608: {'knowledge_id': 'A0020', 'question': '医疗礼品如何报销'},
#  609: {'knowledge_id': 'A0020', 'question': '医疗教学用品如何报销'},
#  610: {'knowledge_id': 'A0077', 'question': '医疗教学用品'},
#  611: {'knowledge_id': 'A0091', 'question': '您好为什么总显示ssl错误'},
#  612: {'knowledge_id': 'A0065', 'question': '无法连接与该服务器的安全连接'},
#  613: {'knowledge_id': 'A0043', 'question': '发送以付款'},
#  614: {'knowledge_id': 'I0008', 'question': '如何下载adobe'},
#  615: {'knowledge_id': 'A0065', 'question': '用户名和密码是什么'},
#  616: {'knowledge_id': 'G0075', 'question': 'esm网址'},
#  617: {'knowledge_id': 'A0095', 'question': '请问刷卡单掉了可以用其他证据代替吗'},
#  618: {'knowledge_id': 'A0040', 'question': '我的报销被退回，我想知道我怎么操作'},
#  619: {'knowledge_id': 'A0050', 'question': '您好，我要报澳门的打车费，交易地点没有澳门，怎么办呀'},
#  620: {'knowledge_id': 'I0001', 'question': '日和下载掌上az'},
#  621: {'knowledge_id': 'I0038', 'question': '收入证明'},
#  622: {'knowledge_id': 'A0087', 'question': '之前财务关账，很多信用卡未关联，现在怎么处理'},
#  623: {'knowledge_id': 'E0001', 'question': '你好我收不到公司邮件'},
#  624: {'knowledge_id': 'A0080', 'question': 'concur刷卡记录导入'},
#  625: {'knowledge_id': 'A0065', 'question': '不能登录conncur'},
#  626: {'knowledge_id': 'A0065', 'question': 'concur怎样登陆'},
#  627: {'knowledge_id': 'A0066', 'question': '如何安装concur到手机'},
#  628: {'knowledge_id': 'I0001', 'question': '如何安装掌上az到手机'},
#  629: {'knowledge_id': 'G0060', 'question': '讲者续签需要多少时间'},
#  630: {'knowledge_id': 'D0004', 'question': '请问阿凡达网址是多少'},
#  631: {'knowledge_id': 'G0036', 'question': '会议时间推迟'},
#  632: {'knowledge_id': 'A0066', 'question': 'sso代码'},
#  633: {'knowledge_id': 'G0036', 'question': '会议修改时间后是否需要审批'},
#  634: {'knowledge_id': 'G0075', 'question': '最近e活动网址无法登陆'},
#  635: {'knowledge_id': 'G0080', 'question': '你好，可以讲e活动中，需要报销的材料以邮件形式发送给我吗？'},
#  636: {'knowledge_id': 'G0067', 'question': '不是咨询需要什么，是最近无法登陆网址，无法下载会议报销材料'},
#  637: {'knowledge_id': 'A0110', 'question': '我的电脑晚上开始无法开机，power键一直闪'},
#  638: {'knowledge_id': 'I0003', 'question': '能不能将报销所需的e活动相关的邀请函面单发送一下'},
#  639: {'knowledge_id': 'I0001', 'question': '安装az app'},
#  640: {'knowledge_id': 'E0029', 'question': 'crm 身份验证失败'},
#  641: {'knowledge_id': 'G0078', 'question': '你好，请问飞检的邮箱是？'},
#  642: {'knowledge_id': 'G0067', 'question': 'esm无法登录'},
#  643: {'knowledge_id': 'F0021', 'question': '你好，几号可以新增客户信息'},
#  644: {'knowledge_id': 'G0005', 'question': '请问esm邮箱是多少'},
#  645: {'knowledge_id': 'G0063', 'question': '劳务费'},
#  646: {'knowledge_id': 'A0065', 'question': 'concur网址'},
#  647: {'knowledge_id': 'I0001', 'question': '请问掌上az怎么下载的呢'},
#  648: {'knowledge_id': 'A0020', 'question': '请问concur 系统报销，循环利息需要怎么处理呢？'},
#  649: {'knowledge_id': 'A0016', 'question': '撤回报告'},
#  650: {'knowledge_id': 'G0005', 'question': '您好，帮忙发一下esm邮箱吧，非常感谢'},
#  651: {'knowledge_id': 'D0004', 'question': '您好，请问一下阿凡达的网址是多少啊？'},
#  652: {'knowledge_id': 'A0066', 'question': 'concur的公司代码是啥来着'},
#  653: {'knowledge_id': 'A0065', 'question': '网页网址'},
#  654: {'knowledge_id': 'A0066', 'question': '公司的sso代码是多少'},
#  655: {'knowledge_id': 'A0065', 'question': 'concur网页版链接'},
#  656: {'knowledge_id': 'A0110', 'question': '人工电话多少'},
#  657: {'knowledge_id': 'G0036', 'question': '但注册会议里面找不到'},
#  658: {'knowledge_id': 'C0001', 'question': '重置k账号密码'},
#  659: {'knowledge_id': 'C0001', 'question': '我的密码忘记了'},
#  660: {'knowledge_id': 'F0021', 'question': '你好新增客户怎么添加'},
#  661: {'knowledge_id': 'A0065', 'question': 'concur 网址'},
#  662: {'knowledge_id': 'G0075', 'question': '今天发现打不开esm'},
#  663: {'knowledge_id': 'I0001', 'question': '手机安装掌上az失败'},
#  664: {'knowledge_id': 'G0075', 'question': '请问ems的网页版网址有吗？谢谢'},
#  665: {'knowledge_id': 'E0029', 'question': '你好，我的veeva登陆显示身份验证失败'},
#  666: {'knowledge_id': 'F0021', 'question': '如何添加客户'},
#  667: {'knowledge_id': 'F0023', 'question': '你好，我在系统中什么地方可以修改客户姓名呀？'},
#  668: {'knowledge_id': 'I0001', 'question': '掌上az下载链接'},
#  669: {'knowledge_id': 'G0075', 'question': 'esm的网站'},
#  670: {'knowledge_id': 'A0065', 'question': '跪求concur网页网站'},
#  671: {'knowledge_id': 'G0068', 'question': '如何取消活动'},
#  672: {'knowledge_id': 'D0004', 'question': '阿凡达网址'},
#  673: {'knowledge_id': 'J0001', 'question': '差旅网址'},
#  674: {'knowledge_id': 'A0066', 'question': '安卓系统如何登录concur'},
#  675: {'knowledge_id': 'A0110', 'question': '人工电话'},
#  676: {'knowledge_id': 'A0039', 'question': '马来西亚财务中心电话'},
#  677: {'knowledge_id': 'F0025', 'question': '这个礼拜没有做kpi对我的绩效考核有影响吗？'},
#  678: {'knowledge_id': 'I0001', 'question': '你好，请问下掌上az有下载链接吗？'},
#  679: {'knowledge_id': 'D0020', 'question': '我的必修课已经完成，怎么公司显示未完成'},
#  680: {'knowledge_id': 'I0001', 'question': '安卓手机怎样下掌上az'},
#  681: {'knowledge_id': 'C0003', 'question': '密码错误？'},
#  682: {'knowledge_id': 'I0001', 'question': '掌上az怎么下载'},
#  683: {'knowledge_id': 'A0098', 'question': '你好，我油费发票开票时，没有开税号，可以报销吗？'},
#  684: {'knowledge_id': 'I0000', 'question': '掌上az闪退'},
#  685: {'knowledge_id': 'I0001', 'question': '安卓手机怎么下载掌上az'},
#  686: {'knowledge_id': 'F0001', 'question': '我的icustomer登录不了'},
#  687: {'knowledge_id': 'I0001', 'question': '收集掌上az闪退'},
#  688: {'knowledge_id': 'C0003', 'question': '我的k账号密码失效了，怎么办'},
#  689: {'knowledge_id': 'D0004', 'question': '阿凡达平台网页版网址'},
#  690: {'knowledge_id': 'D0016', 'question': '实习生在线培训没有课程'},
#  691: {'knowledge_id': 'C0001', 'question': 'k账户密码更改'},
#  692: {'knowledge_id': 'F0001', 'question': 'icustomer登录不上怎么回事'},
#  693: {'knowledge_id': 'A0066', 'question': 'sso公司代码？'},
#  694: {'knowledge_id': 'F0001', 'question': 'icustomer登录不上'},
#  695: {'knowledge_id': 'C0003',
#   'question': '亲，你好我在登陆concur 的界面用手机登，k账号密码都是对的，试了3个人的k账号还是进不去，我把截图发给你们看看'},
#  696: {'knowledge_id': 'I0001', 'question': '掌上az下载'},
#  697: {'knowledge_id': 'I0002', 'question': '掌上az打不开'},
#  698: {'knowledge_id': 'C0003', 'question': '你好，veeca登录密码没设置过，如何登录呢？'},
#  699: {'knowledge_id': 'A0043', 'question': '报销显示已打款 为何没有收到'},
#  700: {'knowledge_id': 'I0007', 'question': '手机微信公众号里的微视角怎么打不开？'},
#  701: {'knowledge_id': 'C0001', 'question': '我的密码可能过期了'},
#  702: {'knowledge_id': 'C0001',
#   'question': '请您帮忙给一个新密码吧，我已失去注册的机会，因为密码已过期，刚才试过了'},
#  703: {'knowledge_id': 'A0110', 'question': '感觉现在的客服服务方式，还不如原来便捷，是我家网络问题吗？'},
#  704: {'knowledge_id': 'I0011', 'question': '如何更改密码'},
#  705: {'knowledge_id': 'C0003', 'question': '让我更改密码，这个用户名填什么呀，是k账号吗'},
#  706: {'knowledge_id': 'D0004', 'question': '网页版阿凡达网址'},
#  707: {'knowledge_id': 'D0005',
#   'question': 'avatarz中，课程一直处于同步状态，无法打开。换了网络依旧不行'},
#  708: {'knowledge_id': 'I0002', 'question': '掌上az打不开怎么办'},
#  709: {'knowledge_id': 'F0021', 'question': '添加客户系统中无法添加客户'},
#  710: {'knowledge_id': 'G0062', 'question': '请问一下老板批了一个市场部的活动申请城市会申请不了怎么办'},
#  711: {'knowledge_id': 'G0062', 'question': '院内会可以申请，城市会不能申请的原因是什么？'},
#  712: {'knowledge_id': 'J0001', 'question': '麻烦问一下差旅系统的网址可以给我一下么？'},
#  713: {'knowledge_id': 'J0001',
#   'question': '2018-1-7 11:09:12 麻烦问一下差旅系统的网址可以给我一下么？'},
#  714: {'knowledge_id': 'G0005', 'question': 'esm邮箱是多少'},
#  715: {'knowledge_id': 'A0066', 'question': 'sso码是多少'},
#  716: {'knowledge_id': 'I0001', 'question': '掌上az登不了怎么办，已经下载下来的'},
#  717: {'knowledge_id': 'I0001', 'question': '掌上az突然无法登入怎么弄'},
#  718: {'knowledge_id': 'C0001', 'question': '能帮我修改一下密码吗？'},
#  719: {'knowledge_id': 'F0001', 'question': '我的k账号密码过期了'},
#  720: {'knowledge_id': 'C0001', 'question': '帮我重置下密码'},
#  721: {'knowledge_id': 'I0006', 'question': '无法使用掌上az'},
#  722: {'knowledge_id': 'I0008', 'question': '您好掌上az总是闪退怎么办'},
#  723: {'knowledge_id': 'G0079',
#   'question': '我本来是1组，但是由于架构调整，现在是2组，成本中心默认是1组，请问怎么修改'},
#  724: {'knowledge_id': 'C0001', 'question': '我需要修改k账号密码'},
#  725: {'knowledge_id': 'F0001', 'question': '更改k账号密码'},
#  726: {'knowledge_id': 'F0001',
#   'question': '我要重置k账号密码，谢谢 15958896143  kfbg078'},
#  727: {'knowledge_id': 'F0003', 'question': 'icustomer 打不开'},
#  728: {'knowledge_id': 'E0001', 'question': '下载不了填拜访的'},
#  729: {'knowledge_id': 'C0001', 'question': '你好 我的密码是不是过期了？'},
#  730: {'knowledge_id': 'C0001', 'question': '您好，可以帮我修改一下密码吗？我的k账号是kkhx394'},
#  731: {'knowledge_id': 'G0067', 'question': 'k账号登陆不上去'},
#  732: {'knowledge_id': 'G0075', 'question': 'esm登陆不上去'},
#  733: {'knowledge_id': 'C0001', 'question': '你好，我密码到期了，麻烦更改一下'},
#  734: {'knowledge_id': 'G0067', 'question': '无法登陆esm'},
#  735: {'knowledge_id': 'G0067', 'question': '改密码后如何在登陆esm'},
#  736: {'knowledge_id': 'I0008', 'question': '今天的掌上az怎么登不上去点开后闪退'},
#  737: {'knowledge_id': 'C0003', 'question': '这边提醒我拜访记录填登陆密码'},
#  738: {'knowledge_id': 'C0001', 'question': '密码已过期'},
#  739: {'knowledge_id': 'E0002', 'question': '我的密码没有错误，却一直无法同步'},
#  740: {'knowledge_id': 'E0024', 'question': '如何确认我的客户已经添加成功'},
#  741: {'knowledge_id': 'I0008', 'question': '掌上az点开之后就闪退了是什么原因'},
#  742: {'knowledge_id': 'K0027', 'question': '电脑启动后输入密码黑屏'},
#  743: {'knowledge_id': 'F0001', 'question': '请帮我重新设置k账号密码'},
#  744: {'knowledge_id': 'F0001', 'question': 'k账号密码过期了'},
#  745: {'knowledge_id': 'C0001', 'question': '您好，帮我重置一下密码'},
#  746: {'knowledge_id': 'C0003', 'question': '我想更换密码'},
#  747: {'knowledge_id': 'I0011', 'question': '我的公司软件密码过期了'},
#  748: {'knowledge_id': 'I0011', 'question': '我得密码过期了'},
#  749: {'knowledge_id': 'C0003', 'question': 'k账号密码忘记了'},
#  750: {'knowledge_id': 'A0065', 'question': '请问如何登陆concur'},
#  751: {'knowledge_id': 'C0001', 'question': '我的密码好像不能用了'},
#  752: {'knowledge_id': 'I0000', 'question': '掌上az为什么不能查奖金了啊？去年还能查，谢谢'},
#  753: {'knowledge_id': 'F0025', 'question': 'icustomer 中如何取消客户关联'},
#  754: {'knowledge_id': 'G0073', 'question': '我想问一下讲者协议必须要直线经理签字吗'},
#  755: {'knowledge_id': 'A0065', 'question': '亲，concur企业na那个登陆码是什么呀'},
#  756: {'knowledge_id': 'C0001', 'question': '需要重置'},
#  757: {'knowledge_id': 'C0001', 'question': 'k账户密码到期'},
#  758: {'knowledge_id': 'E0026', 'question': '现在填不了拜访'},
#  759: {'knowledge_id': 'C0001', 'question': 'k帐号密码到期'},
#  760: {'knowledge_id': 'G0036', 'question': 'esm会议时间有变动，应该怎么解决？'},
#  761: {'knowledge_id': 'A0105', 'question': '私车公用怎么申请'},
#  762: {'knowledge_id': 'C0001', 'question': '密码到期了'},
#  763: {'knowledge_id': 'I0008', 'question': '手机app的掌上az 闪退 是怎么回事'},
#  764: {'knowledge_id': 'A0103', 'question': '报销为什么半个月还不打款'},
#  765: {'knowledge_id': 'I0001', 'question': '下载完掌上az还是不能用'},
#  766: {'knowledge_id': 'I0011', 'question': '你好，麻烦帮忙看一下是不是密码过期啦'},
#  767: {'knowledge_id': 'I0001', 'question': '你好，我的掌上az登陆不进去，怎么回事'},
#  768: {'knowledge_id': 'J0001', 'question': '公司差旅申请系统网址有吗'},
#  769: {'knowledge_id': 'J0001', 'question': '差旅系统'},
#  770: {'knowledge_id': 'C0001', 'question': '密码刚你们已帮忙改了，到还是提示过期'},
#  771: {'knowledge_id': 'J0001', 'question': '国旅运通链接多少'},
#  772: {'knowledge_id': 'C0003', 'question': '你好，麻烦帮我修改一下密码，谢谢'},
#  773: {'knowledge_id': 'J0001', 'question': '机票差旅系统'},
#  774: {'knowledge_id': 'G0005', 'question': 'esm邮箱'},
#  775: {'knowledge_id': 'C0001',
#   'question': '修改邮箱密码，kclx328，身份证后四位：5094 直线经理：解树彬 我的职位：高代'},
#  776: {'knowledge_id': 'I0011', 'question': '您好，我密码过期了，然后导致手机里的邮箱同步不了'},
#  777: {'knowledge_id': 'F0001', 'question': '请问exchange密码就是k账号密码吗？'},
#  778: {'knowledge_id': 'G0001', 'question': '搜索不到新的订单号怎么办?'},
#  779: {'knowledge_id': 'I0008', 'question': '掌上az点击后就快闪怎解决'},
#  780: {'knowledge_id': 'I0008', 'question': '掌上az一直闪退是什么情况？？'},
#  781: {'knowledge_id': 'I0008', 'question': '今天掌上az登陆不上去老是闪退，怎么回事'},
#  782: {'knowledge_id': 'C0003', 'question': '您好，更改登录密码'},
#  783: {'knowledge_id': 'I0005', 'question': '掌上az安装失败 安卓手机'},
#  784: {'knowledge_id': 'I0001', 'question': '你好！掌上az怎么使用呢？'},
#  785: {'knowledge_id': 'A0039', 'question': '马来西亚财务电话'},
#  786: {'knowledge_id': 'G0009', 'question': '我有几笔讲课费超过90天了还没打款'},
#  787: {'knowledge_id': 'I0002', 'question': '掌上az打不开，闪退'},
#  788: {'knowledge_id': 'C0001', 'question': '亲，密码过期了'},
#  789: {'knowledge_id': 'G0080', 'question': '签到表'},
#  790: {'knowledge_id': 'C0001', 'question': '您好，请帮我重置下密码，我的密码过期了'},
#  791: {'knowledge_id': 'C0003', 'question': '如何系统中设置密码'},
#  792: {'knowledge_id': 'G0067', 'question': '密码过期了，怎么进行重置？'},
#  793: {'knowledge_id': 'G0067', 'question': '你好，密码重置怎么操作？'},
#  794: {'knowledge_id': 'A0110', 'question': '7575电话是多少'},
#  795: {'knowledge_id': 'I0008', 'question': '掌上az无法登录，总是闪退 什么原因'},
#  796: {'knowledge_id': 'G0077', 'question': '如何在系统注册参会客户'},
#  797: {'knowledge_id': 'I0001', 'question': '请给我推送掌上az'},
#  798: {'knowledge_id': 'C0003', 'question': '密码查询'},
#  799: {'knowledge_id': 'C0001', 'question': '忘了k账号密码'},
#  800: {'knowledge_id': 'G0077', 'question': '怎么添加参会人'},
#  801: {'knowledge_id': 'E0004', 'question': '我已经提交了5天数据了，查看自依然是0'},
#  802: {'knowledge_id': 'A0110', 'question': '审计中心的电话'},
#  803: {'knowledge_id': 'F0040', 'question': '审计中心的电话和邮件'},
#  804: {'knowledge_id': 'A0110', 'question': '请问3期it服务台有没有电话号码?'},
#  805: {'knowledge_id': 'G0079', 'question': '我想咨询一下我这边申请科室会的成本中心编码'},
#  806: {'knowledge_id': 'C0001', 'question': '过期了'},
#  807: {'knowledge_id': 'C0001', 'question': '我们密码'},
#  808: {'knowledge_id': 'A0066', 'question': '华为手机系统安装concur怎么登录'},
#  809: {'knowledge_id': 'E0001',
#   'question': '咨询问题：veera一直提示更新，但更新不了，我将app删了，需要下载，在az app catalog里找不到了！新版的'},
#  810: {'knowledge_id': 'I0001', 'question': '掌上az无法登陆'},
#  811: {'knowledge_id': 'C0003', 'question': '拜访系统登录账号密码是什么'},
#  812: {'knowledge_id': 'J0001', 'question': '国旅系统无法登陆'},
#  813: {'knowledge_id': 'A0065', 'question': '你好，concur网页版怎么登入'},
#  814: {'knowledge_id': 'A0066', 'question': '我需要公司sos代码'},
#  815: {'knowledge_id': 'A0039', 'question': '扫描中心联系方式'},
#  816: {'knowledge_id': 'C0001', 'question': '麻烦帮我k帐号解锁'},
#  817: {'knowledge_id': 'A0110', 'question': '请问it服务电话是多少'},
#  818: {'knowledge_id': 'I0038', 'question': '开收入证明联系谁啊'},
#  819: {'knowledge_id': 'F0001', 'question': 'icustomer登录用户名是邮箱还是k 账号'},
#  820: {'knowledge_id': 'F0023', 'question': '客户换医院'},
#  821: {'knowledge_id': 'F0023', 'question': '客户更换机构'},
#  822: {'knowledge_id': 'F0023', 'question': '客户更换医院'},
#  823: {'knowledge_id': 'E0029',
#   'question': 'harmony irep登录提示身份验证失败。请联络您的系统管理员'},
#  824: {'knowledge_id': 'I0007', 'question': 'sfe 考核'},
#  825: {'knowledge_id': 'A0066', 'question': 'sso公司代码是多少？'},
#  826: {'knowledge_id': 'A0039', 'question': '扫描中心和审计中心的邮箱各是什么，谢谢啦'},
#  827: {'knowledge_id': 'C0001', 'question': '我veeva打不开了，原因是密码过期了，能帮我把密码改一下'},
#  828: {'knowledge_id': 'I0008', 'question': '掌上az闪退？'},
#  829: {'knowledge_id': 'G0071', 'question': '如何查看讲者申请进度'},
#  830: {'knowledge_id': 'J0001', 'question': '差旅预定网页版网址'},
#  831: {'knowledge_id': 'J0001', 'question': '差旅预定系统网址'},
#  832: {'knowledge_id': 'I0001', 'question': '请问掌上az在哪里下载啊？'},
#  833: {'knowledge_id': 'C0001', 'question': '我的密码过期了，能不能帮我重设一个密码'},
#  834: {'knowledge_id': 'A0039', 'question': '扫描中心电话多少'},
#  835: {'knowledge_id': 'E0002', 'question': '输入k账号的密码说错误'},
#  836: {'knowledge_id': 'E0029', 'question': '拜访没法同步'},
#  837: {'knowledge_id': 'A0088', 'question': '讲课费需要多久下来'},
#  838: {'knowledge_id': 'C0003', 'question': '我的密码忘记了，帮忙更改新密码'},
#  839: {'knowledge_id': 'G0075', 'question': '电脑登陆网页版esm网址多少'},
#  840: {'knowledge_id': 'C0001', 'question': '我的密码是不是快过期了'},
#  841: {'knowledge_id': 'A0039', 'question': '您好，请问审计中心电话是多少，谢谢！'},
#  842: {'knowledge_id': 'C0003', 'question': '怎样登陆esm更改密码'},
#  843: {'knowledge_id': 'J0001', 'question': '差旅预定系统的网址'},
#  844: {'knowledge_id': 'C0003', 'question': '请问可以在线修改k账号密码么'},
#  845: {'knowledge_id': 'C0003', 'question': '可以在线修改k账号密码么'},
#  846: {'knowledge_id': 'G0078', 'question': '飞检邮箱多少'},
#  847: {'knowledge_id': 'E0001',
#   'question': '2018-1-10 12:04:16 irep 不能下载 昨天咨询过 说会后台推送 但是今天还没有'},
#  848: {'knowledge_id': 'E0001', 'question': 'irep 不能下载 昨天咨询过 说会后台推送 但是今天还没有'},
#  849: {'knowledge_id': 'E0001', 'question': '你好 我的ipad里还是没有irep'},
#  850: {'knowledge_id': 'C0001', 'question': '账号密码过期'},
#  851: {'knowledge_id': 'C0001', 'question': 'k账号密码过期'},
#  852: {'knowledge_id': 'I0001', 'question': '我更换手机，请问掌上az怎么安装'},
#  853: {'knowledge_id': 'C0003', 'question': '您好，刚刚更好的k帐号密码登录不上，请求从新更改'},
#  854: {'knowledge_id': 'C0001', 'question': 'k帐号密码过期'},
#  855: {'knowledge_id': 'A0039', 'question': '报销账单扫描中心的邮箱地址多少'},
#  856: {'knowledge_id': 'I0008', 'question': '您好，我的掌上az更新后还是闪退'},
#  857: {'knowledge_id': 'G0081', 'question': '讲者费用查询'},
#  858: {'knowledge_id': 'C0001', 'question': '你好，我的k账号密码到期了'},
#  859: {'knowledge_id': 'C0001', 'question': '您好 重置密码应该选哪个'},
#  860: {'knowledge_id': 'G0081', 'question': '怎么查讲课费是否到账'},
#  861: {'knowledge_id': 'C0001', 'question': '我的k账号密码过期，想修改密码。'},
#  862: {'knowledge_id': 'C0003', 'question': '密码过期，想修改密码'},
#  863: {'knowledge_id': 'F0011', 'question': '奖金申诉'},
#  864: {'knowledge_id': 'A0075', 'question': '水单遗失'},
#  865: {'knowledge_id': 'C0001', 'question': '您能帮我修改一下k账号密码吗'},
#  866: {'knowledge_id': 'C0001', 'question': '您能帮我修改一下k账号密码吗？我的密码过期了'},
#  867: {'knowledge_id': 'A0066', 'question': 'sso公司代码是什么？'},
#  868: {'knowledge_id': 'E0022', 'question': '想咨询一下拜访不合格的申诉在哪里可以申诉呀'},
#  869: {'knowledge_id': 'J0001', 'question': '麻烦发一下差旅的链接'},
#  870: {'knowledge_id': 'I0037', 'question': '您好，biso接收不到奖金政策'},
#  871: {'knowledge_id': 'G0081', 'question': '讲课费账单遗失怎么办'},
#  872: {'knowledge_id': 'C0003', 'question': 'az email密码'},
#  873: {'knowledge_id': 'A0039', 'question': '能否提供一下扫描中心的邮箱？'},
#  874: {'knowledge_id': 'I0001', 'question': '下载掌上az的网址'},
#  875: {'knowledge_id': 'I0038', 'question': '如何打印收入证明'},
#  876: {'knowledge_id': 'I0001', 'question': '下载掌上az怎么弄'},
#  877: {'knowledge_id': 'A0039', 'question': '马来西亚财务电话是？'},
#  878: {'knowledge_id': 'A0110', 'question': '手机拨打7575全部号码是多少？'},
#  879: {'knowledge_id': 'C0003', 'question': '开机密码忘记了'},
#  880: {'knowledge_id': 'I0014', 'question': '实习生考勤'},
#  881: {'knowledge_id': 'J0001', 'question': '差旅的网址是啥'},
#  882: {'knowledge_id': 'A0039', 'question': '请问财务政策在哪里查询'},
#  883: {'knowledge_id': 'J0001', 'question': '差旅系统链接'},
#  884: {'knowledge_id': 'C0001', 'question': '您好密码是不是过期了'},
#  885: {'knowledge_id': 'F0001', 'question': 'icustomer打不开'},
#  886: {'knowledge_id': 'C0003', 'question': '请问，这个系统公司id，用户名，密码是啥'},
#  887: {'knowledge_id': 'C0003', 'question': '电脑密码如何修改'},
#  888: {'knowledge_id': 'I0037', 'question': '奖金政策'},
#  889: {'knowledge_id': 'C0001', 'question': '忘记密码'},
#  890: {'knowledge_id': 'I0000', 'question': '掌上az的安装流程给我一下呗'},
#  891: {'knowledge_id': 'I0000',
#   'question': '亲，请问ipad上面可以安装掌上a?z吗，我一直安装了装上不能用是为什么呢？可以解决吗？'},
#  892: {'knowledge_id': 'C0001', 'question': '怎在这里无法修改密码了'},
#  893: {'knowledge_id': 'J0001', 'question': '国旅运通登录方法？'},
#  894: {'knowledge_id': 'D0004', 'question': '阿凡达网页版地址'},
#  895: {'knowledge_id': 'I0038', 'question': '请问有格式的收入证明怎么开具，不是公司掌上az 的版本'},
#  896: {'knowledge_id': 'I0038', 'question': '请问有格式的收入证明怎么开具'},
#  897: {'knowledge_id': 'C0001', 'question': '我要新密码'},
#  898: {'knowledge_id': 'I0001', 'question': '安卓手机下载掌上az'},
#  899: {'knowledge_id': 'G0084', 'question': '相关记录被锁定，不能更新'},
#  900: {'knowledge_id': 'G0084', 'question': '相关记录被锁定'},
#  901: {'knowledge_id': 'G0067',
#   'question': '为什么我确保用户名和密码准确的情况下登录不了系统，并且一直提示密码错误'},
#  902: {'knowledge_id': 'G0067', 'question': '为什么系统现在登录不了'},
#  903: {'knowledge_id': 'I0037', 'question': '如何获取2018年最新个人奖金制度'},
#  904: {'knowledge_id': 'I0037', 'question': '我想咨询2018年cvx-e的奖金政策'},
#  905: {'knowledge_id': 'C0003', 'question': '你好。旁边忘记锁屏密码。怎么办。刷机还有公司软件吗'},
#  906: {'knowledge_id': 'A0043', 'question': '账单一个月未付款'},
#  907: {'knowledge_id': 'F0021', 'question': 'icustomer如何关联客户'},
#  908: {'knowledge_id': 'A0066', 'question': 'sso'},
#  909: {'knowledge_id': 'I0030', 'question': '我的奖金'},
#  910: {'knowledge_id': 'I0030', 'question': '我的奖金在哪里'},
#  911: {'knowledge_id': 'I0001', 'question': '去哪里下载掌上az'},
#  912: {'knowledge_id': 'C0003', 'question': '登陆密码是什么'},
#  913: {'knowledge_id': 'C0001', 'question': '密码过期重置'},
#  914: {'knowledge_id': 'C0003', 'question': '怎么修改密码'},
#  915: {'knowledge_id': 'C0003', 'question': '我需要更改密码'},
#  916: {'knowledge_id': 'C0001', 'question': '登陆密码过期'},
#  917: {'knowledge_id': 'A0110', 'question': '人工客服电话多少'},
#  918: {'knowledge_id': 'I0038', 'question': '你好 怎么开我的收入证明'},
#  919: {'knowledge_id': 'I0038', 'question': '你好 开收入证明联系谁'},
#  920: {'knowledge_id': 'C0001', 'question': '电脑密码到期，如何更改'},
#  921: {'knowledge_id': 'C0001', 'question': '电脑密码时间到，怎样更改？谢谢'},
#  922: {'knowledge_id': 'C0001', 'question': '你好！我的k帐号密码过期了，请帮忙重置，谢谢！'},
#  923: {'knowledge_id': 'C0001', 'question': '密码到期，如何重置'},
#  924: {'knowledge_id': 'C0001', 'question': '密码到期了，如何修改'},
#  925: {'knowledge_id': 'C0003', 'question': '如何修改密码'},
#  926: {'knowledge_id': 'E0005', 'question': '第一次登录veeva'},
#  927: {'knowledge_id': 'C0001', 'question': 'k账号密码重置kpqp692'},
#  928: {'knowledge_id': 'J0001', 'question': '差旅网页版链接'},
#  929: {'knowledge_id': 'G0037', 'question': '讲病例'},
#  930: {'knowledge_id': 'A0065', 'question': '网业版网址有吗？发我一下'},
#  931: {'knowledge_id': 'J0001', 'question': '请问下我们差旅网址是啥'},
#  932: {'knowledge_id': 'C0001', 'question': '您好，密码过期了，请帮忙重置一下吧'},
#  933: {'knowledge_id': 'G0028',
#   'question': '您好！我的一场活动结束了，为什么没有提交关闭的按键，关闭不了活动'},
#  934: {'knowledge_id': 'G0058', 'question': '科会级讲者'},
#  935: {'knowledge_id': 'A0110', 'question': '服务台电话号码多少'},
#  936: {'knowledge_id': 'G0015', 'question': '院内会可以有几个讲者'},
#  937: {'knowledge_id': 'C0001',
#   'question': '你好，我的密码没有及时更改，导致过期了，我想改密码现在也改不了，而且也登不上掌上az，该怎么做才能改密码？'},
#  938: {'knowledge_id': 'E0024',
#   'question': '你好！icustomer中可以看到客户，但是veeva crm中一个客户没有，esm中也没有'},
#  939: {'knowledge_id': 'C0001', 'question': '更新k账户密码'},
#  940: {'knowledge_id': 'C0001', 'question': '飞检系统的密码？'},
#  941: {'knowledge_id': 'C0001', 'question': '飞检反馈系统的密码'},
#  942: {'knowledge_id': 'I0037', 'question': '我想问下，mr，每月总奖金，有封顶吗？'},
#  943: {'knowledge_id': 'I0000', 'question': '还是闪退'},
#  944: {'knowledge_id': 'I0000', 'question': '我的掌上az打不开'},
#  945: {'knowledge_id': 'C0001', 'question': '您好！密码过期，麻烦帮我重置，谢谢'},
#  946: {'knowledge_id': 'C0001', 'question': 'k账户密码好像过期了'},
#  947: {'knowledge_id': 'C0001', 'question': '您好，我的密码好像过期了'},
#  948: {'knowledge_id': 'I0000', 'question': '你好，掌上az闪退怎么办'},
#  949: {'knowledge_id': 'F0002', 'question': '请问:icustomer突然登录，网页版也登录不了'},
#  950: {'knowledge_id': 'C0003', 'question': '需要更改密码'},
#  951: {'knowledge_id': 'A0065',
#   'question': '你好！我新代表的ipad登陆concur后会跳出这个界面，再次输入账号密码，老显示错误'},
#  952: {'knowledge_id': 'E0029', 'question': '我的irep一直身份验证失败'},
#  953: {'knowledge_id': 'E0022', 'question': '拜访如何申诉'},
#  954: {'knowledge_id': 'C0003', 'question': '换密码'},
#  955: {'knowledge_id': 'C0001', 'question': '公司系统密码到期'},
#  956: {'knowledge_id': 'C0003', 'question': '密码修改'},
#  957: {'knowledge_id': 'A0066', 'question': '下载了concur app'},
#  958: {'knowledge_id': 'A0065', 'question': 'concer网页电脑平板都打不开'},
#  959: {'knowledge_id': 'C0003', 'question': 'esm提示需要更改密码'},
#  960: {'knowledge_id': 'A0094', 'question': '高铁纸质发票丢失'},
#  961: {'knowledge_id': 'J0001', 'question': '您好！能麻烦您发一个内网差旅系统的网址给我么？'},
#  962: {'knowledge_id': 'A0110', 'question': '求公司心理热线电话'},
#  963: {'knowledge_id': 'A0110', 'question': '亲，请问公司心理热线电话是多少？谢谢你噢'},
#  964: {'knowledge_id': 'G0078', 'question': '讲完科会后，怎样看飞检的反馈？'},
#  965: {'knowledge_id': 'I0000', 'question': '您好掌上az进不去闪退'},
#  966: {'knowledge_id': 'E0022',
#   'question': '2018-1-15 09:23:04 您好，请问嫌疑拜访的申诉在哪里可以申诉呀'},
#  967: {'knowledge_id': 'E0022', 'question': '您好，请问拜访申诉在哪里可以呀'},
#  968: {'knowledge_id': 'C0001', 'question': '我的k帐号密码过期了，请帮忙重置，谢谢！'},
#  969: {'knowledge_id': 'C0001',
#   'question': '我手机上的企业微信端查询本月ddi每次都让输入k账号和密码，请问这个怎么接 blue'},
#  970: {'knowledge_id': 'J0001', 'question': '你好，我登录不了国旅运通的主页'},
#  971: {'knowledge_id': 'I0000', 'question': '您好 可以发一个掌上az的二维码嘛'},
#  972: {'knowledge_id': 'A0075',
#   'question': '我想咨询一下手写发票可以报销吗，因为我在池州开会，这边没有机打的发票'},
#  973: {'knowledge_id': 'C0001', 'question': '您好 能不能帮忙修改一下公司密码'},
#  974: {'knowledge_id': 'C0001', 'question': '您好 我的公司密码过期了 怎么修改密码'},
#  975: {'knowledge_id': 'A0010', 'question': '易活动没有导入'},
#  976: {'knowledge_id': 'I0037', 'question': '个人定制版的奖金政策'},
#  977: {'knowledge_id': 'A0094', 'question': '菜单丢失'},
#  978: {'knowledge_id': 'C0001', 'question': '更新密码'},
#  979: {'knowledge_id': 'C0001', 'question': '密码忘记啦'},
#  980: {'knowledge_id': 'J0001', 'question': '我要出差需要预定差旅机票'},
#  981: {'knowledge_id': 'C0001', 'question': '我刚刚是按照这个更新的，现在输入密码无法登录'},
#  982: {'knowledge_id': 'C0001',
#   'question': '你好，我自助密码更新不成功，麻烦帮忙看一下现在是哪个密码，谢谢。'},
#  983: {'knowledge_id': 'I0000', 'question': '安装后不能使用'},
#  984: {'knowledge_id': 'I0001', 'question': '掌上az不能使用 怎么办'},
#  985: {'knowledge_id': 'G0067', 'question': '请问esm系统怎么登陆不进去呢'},
#  986: {'knowledge_id': 'I0008', 'question': '你好，请问手机的掌上az出现闪退，如何处理呀'},
#  987: {'knowledge_id': 'A0066', 'question': '如何登录concur手机版'},
#  988: {'knowledge_id': 'A0110', 'question': '电话'},
#  989: {'knowledge_id': 'C0003', 'question': '更换密码'},
#  990: {'knowledge_id': 'D0004', 'question': '您好我想咨询下阿凡达网页版网址'},
#  991: {'knowledge_id': 'C0001', 'question': '您好，我的密码过期了，可以帮忙更改吗'},
#  992: {'knowledge_id': 'F0023', 'question': '怎么icustomer里面客户修改信息改不了'},
#  993: {'knowledge_id': 'A0066', 'question': '公司concur的公司代码多少'},
#  994: {'knowledge_id': 'G0069', 'question': '不小心误取消了活动 可以恢复吗？'},
#  995: {'knowledge_id': 'A0094', 'question': '请问pos单遗失怎么办？谢谢！'},
#  996: {'knowledge_id': 'G0067', 'question': '亲我这转行后一直登陆不上，更新过了'},
#  997: {'knowledge_id': 'A0020', 'question': '信用卡出现循环利息怎么办'},
#  998: {'knowledge_id': 'I0001', 'question': '手机下载掌上az为什么不能用'},
#  999: {'knowledge_id': 'I0000', 'question': '你好，我的掌上az打不开了'},
#  ...}

# %%
print(type(str(7575.0)))
# Out:
# <class 'str'>

# %%
# 第二种文本特征提取方式：Word2Vec

# %%
# 第三种文本特征提取方式：CountVectorizer-One Hot类型的，此处就不取了
